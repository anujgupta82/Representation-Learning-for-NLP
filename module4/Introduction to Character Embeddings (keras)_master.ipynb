# %% [markdown]
# #### Agenda - Given a sequence of previous characters, model the probability distribution of the next character in the sequence.
#
# Here we try harry potter text
#
# We will be using kears for this note

# %%
from __future__ import print_function

import numpy as np
import random
import sys

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Get data

# %%
# load data
path = "./../data/harry_potter_3.txt"
text = open(path).read().lower()
print('corpus length:', len(text))
# Out:
# corpus length: 626260

# %%
total_chars = sorted(list(set(text)))
print('total chars:', len(total_chars))
# Out:
# total chars: 54

# %%
#dictionaries to map characters to IDs and vice-a-versa

char_indices = dict((c, i) for i, c in enumerate(total_chars))
indices_char = dict((i, c) for i, c in enumerate(total_chars))

# %%
# cut the text in semi-redundant sequences of maxlen characters

maxlen = 40 # length of data window
step = 1    # step by which to shift the data window 

sentences = []    # this stores X
next_chars = []   # this stores y

# (i:i+40) as X, (i+40) as corresponding y
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen]) # get sentence
    next_chars.append(text[i + maxlen])   # get next character
    

num_of_sentences = len(sentences)

print('Number of datapoints/sequences:', num_of_sentences)
# Out:
# Number of datapoints/sequences: 626220

# %%
#Vectorize the input 

# X will be a 3D tensor - num_of_sentences * maxlen * total_chars
# y will be 2D tensor - sentences * total_chars

print('Vectorization...')
X = np.zeros((num_of_sentences, maxlen, len(total_chars)), dtype=np.bool)
y = np.zeros((num_of_sentences, len(total_chars)), dtype=np.bool)

# populate the tensors
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Vectorization...

# %% [markdown]
# # Model

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()

# lstm takes a single slice of 3D tensor along num_of_sentences axiss
model.add(LSTM(128, input_shape=(maxlen, len(total_chars)))) 

# add a dense layer - takes 128 input and spits output of num_of_chars 
model.add(Dense(len(total_chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# Build model...

# %%
#Preds is scores over output space (characters)
# Its nothing but - confidence the RNN currently assigns to each character coming next in the sequence

# we convert scores into probability distribution and pick the best bet. 

# Temperature. We can also play with the temperature of the Softmax during sampling. Decreasing the temperature 
# from 1 to some lower number (e.g. 0.5) makes the RNN more confident, but also more conservative in its samples. 
# Conversely, higher temperatures will give more diversity but at cost of more mistakes (e.g. spelling mistakes, 
# etc). In particular, setting temperature very near zero will give the most likely thing

def sample(preds, temperature=1.0):
    
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds) # convert scores to prob via softmax
    probas = np.random.multinomial(1, preds, 1)
    
    return np.argmax(probas) # return the one with max probability

# %%
for iteration in range(1, 60):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    model.fit(X, y,batch_size=128,epochs=1)
    
    start_index = random.randint(0, len(text) - maxlen - 1) # pick an index at random
    
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print()
        print('----- diversity:', diversity)
        
        generated = ''
        sentence = text[start_index: start_index + maxlen] # pick sentence at randomly gerenated index
        generated += sentence
        
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)
        sys.stdout.write("\n")
        
        for i in range(400):
            x = np.zeros((1, maxlen, len(total_chars)))
            for t, char in enumerate(sentence):
                x[0, t, char_indices[char]] = 1. # put the sentence in 1-hot format
                
            preds = model.predict(x, verbose=0)[0] # make the model spit out predictions
            
            next_index = sample(preds, diversity) # choose a character index
            next_char = indices_char[next_index]  # get the corresponding chracater
            
            generated += next_char                # append this character to the sentence
            sentence = sentence[1:] + next_char   # now shift the the sentence by one character
            
            sys.stdout.write(next_char)           # write the character to buffer
            sys.stdout.flush()
            
        print()
# Out:
# --------------------------------------------------
# Iteration 1
# Epoch 1/1
# 626220/626220 [==============================] - 711s - loss: 1.6393
#
# ----- diversity: 0.2
# ----- Generating with seed: " hermione approvingly. "but i
# wish i co"
#  hermione approvingly. "but i
# wish i co
# mpletely behind the stare and the desk. "i said and hermione stare the stare the stare of the start of the should the match and said and hermione said and hermione the start of the start and hard the stare of the wand to the stare of the slipped the start of the stare and the the should the wand to the transformed the transform the bed the stare to the should the the mather behind the stare and st
#
# ----- diversity: 0.5
# ----- Generating with seed: " hermione approvingly. "but i
# wish i co"
#  hermione approvingly. "but i
# wish i co
# me him toward the dest to his come the steeling him of the
# great and the broke the face spetting the trair on the slime. he looked still over the himper and behind it. "where about the firebolt, than him to peroup, and he said a snape and looked one of
# reached the stare and harry and should feet a sime a heart to see the visitsing. the tranding the castle. "and harry and hermione were was them o
#
# ----- diversity: 1.0
# ----- Generating with seed: " hermione approvingly. "but i
# wish i co"
#  hermione approvingly. "but i
# wish i co
# uld three, ron's endiwlityh, hagrid to him was must trance
# noishs.
#
# "jum" ig should like the were ron, harry file around anootely clanger!" said hermione had been lone.
#
# "snan one across the member a hatus.
# "sha.... there was i's wo'rt, enougs happitrings."
#
# "wene you trolly himes-lattert about we're green, with the abress byly hall come neccousfufuling and weoxed thas caldle. it was sure
#
# ----- diversity: 1.2
# ----- Generating with seed: " hermione approvingly. "but i
# wish i co"
#  hermione approvingly. "but i
# wish i co
# nfictages?" "oke percymask, his winage spoasy famefh behind himself. "they
# kenphise, himance eh, hermione towing
# a who-ricious afe, arm entertably, shaking ut
# day take iw hermione roofs rhtomman flone --"
#
# "yeurm. once are you with whi search were blowous.rite, lostle weahgered. in his billide.
#
# "jus. dat mean, lupped hilo, snuteringring dreamhhe wlioning ghedly thome know... grown fiwstly
#
# --------------------------------------------------
# Iteration 2
# Epoch 1/1
# 626220/626220 [==============================] - 709s - loss: 1.4094
#
# ----- diversity: 0.2
# ----- Generating with seed: "ll... we'll know day after tomorrow -- o"
# ll... we'll know day after tomorrow -- o
# n the came of the castle.
#
# "the match -- be a come on the dementors and hear the firebolt and hermione became the commit the castle. "you didn't think the match -- they want to be a start of the tair and gone to the common things and the match. the common to her best the match.
#
# "he was the match -- there was a common to be the common to get the comment of the firebolt.
#
# "the trunk, he want
#
# ----- diversity: 0.5
# ----- Generating with seed: "ll... we'll know day after tomorrow -- o"
# ll... we'll know day after tomorrow -- o
# ne of the dementors was the dementor. they were a breath.
#
# "come under the cate any one to the dementor over the mind in his werewhand and was than the wingloor that he came the match, but a grinnical seemed to be a burite that a bottation and proppet and hermione, and "sawe that some again, master, that was a ron si came and then the comtansifically and been himself was tone in the cormint of t
#
# ----- diversity: 1.0
# ----- Generating with seed: "ll... we'll know day after tomorrow -- o"
# ll... we'll know day after tomorrow -- o
# ld scrange,
# goven?"
#
# malfoy' kcearing growning. eansiage that get on the
# fear glatcups to any minder the floor. the dassinelize what them landingly ground
# posts rack! gave that say an the nowfully. minvee unlange fellon. the dementors was many count.
#
# " matmermo-col trees shart," he came with a lips his mind
# harry raised a
# fie back of the sleer with the presently mrank
# of the damber. thi
#
# ----- diversity: 1.2
# ----- Generating with seed: "ll... we'll know day after tomorrow -- o"
# ll... we'll know day after tomorrow -- o
# pene i --
#
# the bits into his learcwill foew a lege in.
# parvanis," said. aunt reasing him's ten clup. snap. there was holding the
# front snitbentmloseable fronthey to be pockent clupsting dockor of an
# now, thilly were don't?" said harry. "getperarable was's befted trest,
# what he wouldn't be ?"i'qup nar, but was sand telp wem tuiness me there were
# badrid aventlong boated, whisplechad modiening
#
# --------------------------------------------------
# Iteration 3
# Epoch 1/1
# 626220/626220 [==============================] - 712s - loss: 1.3619
#
# ----- diversity: 0.2
# ----- Generating with seed: ". "and scabbers was here first,
# and he'"
# . "and scabbers was here first,
# and he'
# s been the silver and harry said harry had harry said harry said harry said harry said harry said harry said harry said harry and ron had the bown the hands and the starting off the care of the bown of the shoulder and the dementors and she said harry had been the this that he was harry was the firebolt with a side of the matter the this the common room that he was the hands and she was still was
#
# ----- diversity: 0.5
# ----- Generating with seed: ". "and scabbers was here first,
# and he'"
# . "and scabbers was here first,
# and he'
# s seen and points with a sirnus to dementor could have an she beated the common took the sopport of the firebolt was any night that he was a professor lupin remembered to be as we send the
# /home/ubuntu/.virtualenvironments/representation_learning_workshop/lib/python2.7/site-packages/ipykernel_launcher.py:15: RuntimeWarning: divide by zero encountered in log
#   from ipykernel import kernelapp as app
#  friends and hermione. "i was all harry was lord in the lade of harry had hermione was only
# down the moment of the disappioned cold of his third that moon beared the time of the books and he said the bring as he
#
# ----- diversity: 1.0
# ----- Generating with seed: ". "and scabbers was here first,
# and he'"
# . "and scabbers was here first,
# and he'
# s been late let anyone caulder,
# "if not oping --" harry sillle zocking and ser intoine still was there aur
# dait ce'se harry had disappeared back underrors ale
# tried time anooth mutterened prowes; down och the squinrs something was
# flornertalling harry to year entang up browing. malfoy's fiedd offpite
# like and lade. and the crookshoping was night win leck on the
# parthtrice. went it in the en
#
# ----- diversity: 1.2
# ----- Generating with seed: ". "and scabbers was here first,
# and he'"
# . "and scabbers was here first,
# and he'
# s been taving toward a fight todenles.
#
# but madam roam ochad .
#
# "i'm she was push on pulling id. dirles to
# its rlaorer.
#
# "i was thist inage one of misto flom, ill. that pushed form, until had somebody
# didn't winds,
# that she "that'see what iadour it's werewore,kar
# we comes sight," untioned a was heated crack, but more
# right, roared bomnning.
#
# "sachmern, "as, it's in.... harry?" said r
#
# --------------------------------------------------
# Iteration 4
# Epoch 1/1
# 626220/626220 [==============================] - 707s - loss: 1.3359
#
# ----- diversity: 0.2
# ----- Generating with seed: " else had?
#
# professor lupin had come b"
#  else had?
#
# professor lupin had come b
# uckbeak's stranger the desk the firebolt to the strange of him buckbeak's strange of the ground and the staircase of the common room of the castle with the stringe of the started to the man and started to him in his straight in the sign of the corner and the trunk of the castle. he was the desk the common room of the started in the started to the desk to the ground and straighted the constrant. he
#
# ----- diversity: 0.5
# ----- Generating with seed: " else had?
#
# professor lupin had come b"
#  else had?
#
# professor lupin had come b
# outh the rest of his own with the spoke of his sound of his bed to the witch that seemed to harry had
# couned the firebolt for the ground bucking the dementors to him. "i've got off the
# sound the bed off a a marking for countered made them a strange bown of marge's head. he was this grown at the back of the long as
# made a coving harry bed, in the parkin away. he had a street of his head to the d
#
# ----- diversity: 1.0
# ----- Generating with seed: " else had?
#
# professor lupin had come b"
#  else had?
#
# professor lupin had come b
# uckbeak's torm in witch. they wau
# vislip... that opened, something .
#
# "snowly magin geor, saving howch, silently. staring
# -- "but misening, they been parcel."
#
# "but admitser-.
# all bent were around the conver of che down more his head esit melly. a croaks of perce. he
# caritarches balmal better thrith his mack oft
# pettigrew.
#
# harry fleek looking though iundy.
#
# "camecous long!" cry"ble.
#
# ----- diversity: 1.2
# ----- Generating with seed: " else had?
#
# professor lupin had come b"
#  else had?
#
# professor lupin had come b
# befts seerting virentment, towerivi
# glancine. harry, ro quite quicked to vislefe," shit saws
# wee
# listened insteaking vis fius on thinging mevore,
# " poded stookaymalide," said haroyss.
#
# "bulking you ajames forward?" ron smoodling the firdoust flay,
# headmasted; itveredly "we're dorm, a
# agon't brotkerevheund op before run."
#
# yes," squinging up i said into the air mere, degame casted them di
#
# --------------------------------------------------
# Iteration 5
# Epoch 1/1
# 626220/626220 [==============================] - 704s - loss: 1.3213
#
# ----- diversity: 0.2
# ----- Generating with seed: "still not saying i believe you," he told"
# still not saying i believe you," he told
#  him at him. "i said harry's silver way to here in the countly that he was still the silence was the more of the silver the start of his chance of the dementors and the door of the time the team was still had had the staircase of the silver back of his shower and still was the beak of his more that he was the teacher of his malicious team and harry was the counter and spend off his silver was stil
#
# ----- diversity: 0.5
# ----- Generating with seed: "still not saying i believe you," he told"
# still not saying i believe you," he told
#  him. harry counted him in a but of his hands out of the class harry's gryffindor care and a aunt of a stand of his wand off the passing and her
# hands to have a finally seemed to the firebolt could are you said it was a professor mcgonagall -- come on his suppores in his incenting the saw something was something as he was silently. "how see i thought he's a driver
# you to say and muggle a committ
#
# ----- diversity: 1.0
# ----- Generating with seed: "still not saying i believe you," he told"
# still not saying i believe you," he told
#  you lead. harry had heard him, particalling the aunts out and
# arniching the full of orts and anythered to
# malfoy -- up around lept harry's ministry of their off that -- next turn, sirius dumbledore, who benting in his shair stopper, asking caught him and the dementor harry's
# croak into the know up
# his new wandor had turn to see his traindectical is --
# harry bulve it before black evering. "ha
#
# ----- diversity: 1.2
# ----- Generating with seed: "still not saying i believe you," he told"
# still not saying i believe you," he told
#  the class on sight had "dumbledor ensistlypous the boggay de; ties you will be could
# eh'd time him? everyone that? he's found
# against you like chatcimake beat mr. ni, and i howe here
# needer, marry thg, and haq, howeven, they ween
# christing ago... fallenish them off ell mo.yt; his no sirtly
# bowed a bdle. sudden hagming over black suby around.
#
# --m? eyes bo
# -- harry's too nigion, but the ex
#
# --------------------------------------------------
# Iteration 6
# Epoch 1/1
# 626220/626220 [==============================] - 704s - loss: 1.3094
#
# ----- diversity: 0.2
# ----- Generating with seed: " i'd like to
# see the disguise that coul"
#  i'd like to
# see the disguise that coul
# d be thinking the stand and the trunk and the stand and the stand to the dementors was the stand and thing the parents was the trunk and the stand and the stands of his chair of the chect of the stands of the stand and started to him and was the stands of the staircase of the stands of the stand and anything the parents was staring and company, and hermione saw the castle picked and started to the
#
# ----- diversity: 0.5
# ----- Generating with seed: " i'd like to
# see the disguise that coul"
#  i'd like to
# see the disguise that coul
# d have a good carressing
# of the snitch of them, he had to think that about... he was started the time and the paper and the start. they really see what harry, harry, and the bedged and was a bit
# behind the dark around to get the portrait worst man spinning windows through the school to side and smalling to the feeliver. harry like the a a companies of the corridors. he had been for the room was
#
# ----- diversity: 1.0
# ----- Generating with seed: " i'd like to
# see the disguise that coul"
#  i'd like to
# see the disguise that coul
# d
# not destruey, was in scabbers, to that romved the moment poutily honeyd; "ron walks off around. thich wann -- now,
# not the legg?"
#
# "now?" said professor trelawney's 'inesy heads himk skile. my list sleak windic was quirtly over on pettigrew."
#
# "theny hagrid slumek weariut... send their found incuriously
# ofn, then rumned anarnty, but he saw to loudly amid in their sopestly, it," said dumbl
#
# ----- diversity: 1.2
# ----- Generating with seed: " i'd like to
# see the disguise that coul"
#  i'd like to
# see the disguise that coul
# dn't  regaput? slee'spdo's'bleon sirius?" puttedly to his
# gave his over frantiously, crookshankretesly o's dos, what
# the roncee smulls aroy'sn't hupy to professor lupin
# a cut that....
#
# listed the chousing talder to by the toolig. "er --
# she wa'll," said harry, a,' seely dad pointrout,
# 'tium upandigone, hermione's looki hair. " beele hawkm for viey
# silking ?" i lieve to aspleing his an!"
#
#
# --------------------------------------------------
# Iteration 7
# Epoch 1/1
# 626220/626220 [==============================] - 713s - loss: 1.3019
#
# ----- diversity: 0.2
# ----- Generating with seed: " came to watch the quidditch, of course."
#  came to watch the quidditch, of course.
#  he saw the firebolt on the firebolt on his hands and was hands on the team had been shouting toward the forest with hagrid was still was still the castle.
#
# "what was a sleep on the sleep, harry, who was the castle.
#
# "what was a look of the match of the match
# had been the wand of the castle was still of the start of the castle.
#
# "what was a look of the way and the way and hermione was still
#
# ----- diversity: 0.5
# ----- Generating with seed: " came to watch the quidditch, of course."
#  came to watch the quidditch, of course.
#  harry was still can and he was and the door.  he doing
# sight and he had been the end of the arcsleas, harry looked at him speaked to harry's before nothing the spenger toward the least without were
# been for his own crowd with an and the end of the wand and sigged over the wandical point of the stuff with the mad.
#
# "what was a particularly onest all one parchment.
#
# "yes, harry, what's a face
#
# ----- diversity: 1.0
# ----- Generating with seed: " came to watch the quidditch, of course."
#  came to watch the quidditch, of course.
#  a chect.
#
# whispered forward, laughinged cad as he people.
#
# "calm, throon, harry many neville, paining about magic weten in the worm nomua, iske think would
# went her're, his factet, and then, his got on with
# the violen clowle at them and step sa anguise potter -yzinking
# botter and gryffinsle. "you're the firebome it.
#
# there was madam woomd to teacher pettigrew; he voie
# looking, teetended
#
# ----- diversity: 1.2
# ----- Generating with seed: " came to watch the quidditch, of course."
#  came to watch the quidditch, of course.
#
#
# "rightels, bent is they wouldn't kmar's,
# t in onoture."
#
# pehame, mortimy. then it was tog other with it. but ron and i left me voice he's be.
#
# "yeh noteric, i helted it. unsenten .u eyed bobbod.
#
# "into me, or thick that?" she sank freetily. "enngue, he open you fudge! he's away's whocoke
# haided toward the time. the lattericulp.
#
# harry was griem his only dangerous just overs
# tights b
#
# --------------------------------------------------
# Iteration 8
# Epoch 1/1
# 626220/626220 [==============================] - 714s - loss: 1.3027
#
# ----- diversity: 0.2
# ----- Generating with seed: "anic. she looked as though she was about"
# anic. she looked as though she was about
#  the start of the need and was staring and all so harry had hermione and ron was a feeling to harry and ron was standing at him.
#
# "what was a hand and leave the dementor was the starting on the was the
# corner of his eyes was his fingers and hermione started to harry and ron, who was a long of the boy, he was stretched at the first the starting of the was the crowd. he was staring at him.
#
# "wh
#
# ----- diversity: 0.5
# ----- Generating with seed: "anic. she looked as though she was about"
# anic. she looked as though she was about
#  the
# wardrobe for the counts of made the was staring around the feet.
#
# harry had hermione side. "was going to do what i put off!"
#
# he said said. "we're interester his staircase of for a seemed to be a
# few dead seemed to really that he was the supposed to be was all and in an eyes.
#
# "which was a think it was the said," said ron, and the pales.
#
# harry was standing to his wand behind the ha
#
# ----- diversity: 1.0
# ----- Generating with seed: "anic. she looked as though she was about"
# anic. she looked as though she was about
#  it
# maden's," hunfwelled adding frozen --"
#
# harry and hermione followes together on the
# dinoct.
#
# nobodged that to filtet with he alone into the fele. she happened un siled for eyes. "she have, thece spdack please lail eatil. they came away. inholess. as he saw controlluply forget broom. expecto pencing
# at with it. when he wari-t!" snew called on a
# gringshlan sbookly toward meanting lupin w
#
# ----- diversity: 1.2
# ----- Generating with seed: "anic. she looked as though she was about"
# anic. she looked as though she was about
#  about danged
# as peesd was to hitty, but he wrippens in you toward the batters.
# neville?" hrosed him back out with gotrticages, made
# himself to dverrickeated up to his white
# school off the bhatter of yourk, he had they
# whick howlved old seemed up," "how have, wentpding
# durss," said "how haven't jusped unto him,, professor all about the ipgipales rearizen
# puring firally, wud of very, tanpts
#
# --------------------------------------------------
# Iteration 9
# Epoch 1/1
# 626220/626220 [==============================] - 714s - loss: 1.2958
#
# ----- diversity: 0.2
# ----- Generating with seed: "ck from hogsmeade," harry lied
# quickly."
# ck from hogsmeade," harry lied
# quickly.
#  "where was and the ministry on the dark arts to the grass of his cheer shop of his barried of the first than the class that he was harder the class than he was still and the start of the windows and the start of the first than the staircase of the window with a look of the class that he was staring and still that any monds the class of his start of the back of the crowd than the common room with
#
# ----- diversity: 0.5
# ----- Generating with seed: "ck from hogsmeade," harry lied
# quickly."
# ck from hogsmeade," harry lied
# quickly.
#
#
# "and this that the ministry on the boggart on the common one of the start of his head of the magic the end of the mind in the
# classrat.
#
# "yes," said hermione said play the close to feel our bed the windows in the cloak and watch on the broomstick to a single of the first of the black with the common room in the dark and something than seemed his hand of his own sudden shaking back to the gr
#
# ----- diversity: 1.0
# ----- Generating with seed: "ck from hogsmeade," harry lied
# quickly."
# ck from hogsmeade," harry lied
# quickly.
#  "you've been him chase you mightn' know, but we from with
# it.... that hard what i would get it," said harry
# and quickly with our black crow, and appointed white sweight, black had vernon smalled
# something staring over timinous any firebolt. pair.
#
# it was a few i later thans he and their struly
# of down wead. expectolse in the more in the
# hat have sprived up dursless.
#
# he looked heavys. th
#
# ----- diversity: 1.2
# ----- Generating with seed: "ck from hogsmeade," harry lied
# quickly."
# ck from hogsmeade," harry lied
# quickly.
#  "what was banly, you stumf," said har? shung 'spiky know the hlan crashin,
# george. get --"
#
# nothing with a lawer behind his who, h xad after from honeydleout most less
# curntled your tailily heavy dom walldy of breath.
#
# "well... you r you -- he ourselfous lubal toe fan at him this pantay droom.
# foo, half it willy
# "did crookshanks don't sicne? if thmosusples like the potter. he, runilse ro
#
# --------------------------------------------------
# Iteration 10
# Epoch 1/1
# 626220/626220 [==============================] - 715s - loss: 1.2950
#
# ----- diversity: 0.2
# ----- Generating with seed: "ey disappeared
# for a couple of hours an"
# ey disappeared
# for a couple of hours an
# d he was a common one of his hand as he was harry was a few the staring of his head and hermione was the start of the firebolt of his face to the start of his face was the firebolt as he was a corner of the door of his face was for the castle of his bag of harry was the firebolt and he saw the stand shouting started and strode as he sat the start.
#
# "what was a broom that he was a stairs, and the
#
# ----- diversity: 0.5
# ----- Generating with seed: "ey disappeared
# for a couple of hours an"
# ey disappeared
# for a couple of hours an
# d they crouved the back of his book as they had
# bouring the sligxgless to himself to him large. it was to hear the start wand as harry was a hand...."
#
# harry was until or he could do with a care of the books of harry's limping feet under the floor, and he was ron. "he was
# coming seized when i want to can't pers thing they were transforment to the same of the other staircase to really had been
#
# ----- diversity: 1.0
# ----- Generating with seed: "ey disappeared
# for a couple of hours an"
# ey disappeared
# for a couple of hours an
# d say about hogwarts efn
# queed onto these look of now, they knew openeste
# light like a pottert and singer need his
# mind wand dudsquiding viryhind he whocold somecover, when you gave you
# out count to bause..."
#
# "he hall underullal here's never be pipe broomstill
# after security horrible, clup and very my time at
# harry, "sen me around him i weel," said ron
# cloaks of very stride uturiblous hog
#
# ----- diversity: 1.2
# ----- Generating with seed: "ey disappeared
# for a couple of hours an"
# ey disappeared
# for a couple of hours an
# d with laughtted the last about
# lefther.... on them.
#
# "paw -- of armacroufky! tng, folloune to
# it--- afrerodey
# if we.y."
#
# hagrid wasly arguing in.
#
# betwore, burstsisted patur before edio hasn't dumbledor,
# it!" said harry face bang to degagrif its sair, when it was dodga not doing with patmirring. what steps," said beaked. "look into that okay's
# oll
#  door out your anyceo
# feet from want
#
# --------------------------------------------------
# Iteration 11
# Epoch 1/1
# 626220/626220 [==============================] - 715s - loss: 1.2937
#
# ----- diversity: 0.2
# ----- Generating with seed: "ifty
# points from slytherin! i shall be "
# ifty
# points from slytherin! i shall be
# the castle.
#
# "what?" said harry.
#
# "what was the chance of the transformall and hermione was still to see him a few head to the slytherin said and hermione was a few a few the staircase to the first thing --
#
# "what was the castle on the dementors were this was a start of the castle.
#
# "he could hear the castle, they were hermione and hermione was a secret-real was the common room of the feet
#
# ----- diversity: 0.5
# ----- Generating with seed: "ifty
# points from slytherin! i shall be "
# ifty
# points from slytherin! i shall be
# all the whole -- he had ter the shadow.
#
# "they had never bet hermione caught the first time a burst than the castle.
#
# "this wasn't the sound of there was the teached.
#
# "see the thing us again in the castle, then he
# said scabbers and the ron had to flance and shouted.
#
# "see make the best more to kill the time to go to his team the school and flooded to the truth and the door. they was a re
#
# ----- diversity: 1.0
# ----- Generating with seed: "ifty
# points from slytherin! i shall be "
# ifty
# points from slytherin! i shall be
# red acrec""t-took inwermom ear angers. while held muggle into harry. they walk him nearly
# seemed to go on father. harry had been will oft?"
#
# the very disterbidions, and hedwig's offetche that would are i won't
# look 'e tho put the
# mond the rat beak match he had then inside hermione tepped
# and ipvers blacky, tret off you? hour by long
# chain acdair chart from the hiddy wand turn into these thu
#
# ----- diversity: 1.2
# ----- Generating with seed: "ifty
# points from slytherin! i shall be "
# ifty
# points from slytherin! i shall be
# this is givel like
# he'd better catch might make hid as rat? she luug!" said creeps an
# neck. sbutcy goorotstably... "you a broins ten fatforry of honeyduersway from assure of porportain
# onther, whirled inside. himsely escue your longer.
# a what, quied. shakn, like her things, next
# un toao the purfurred cluddingoped midners.
# his book of soctol of let after fortreight!
# you told thectoncty?"
#
#
#
# --------------------------------------------------
# Iteration 12
# Epoch 1/1
# 395776/626220 [=================>............] - ETA: 264s - loss: 1.2928
