# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # A simple sentiment prototype

# %%
import os  # manipulate paths
import pandas as pd  # SQL-like operations and convenience functions
import joblib  # save and load models

# %% [markdown]
# Download the Sentiment140 data from [their website](http://help.sentiment140.com/for-students) or directly from [Standford site](http://cs.stanford.edu/people/alecmgo/trainingandtestdata.zip) and set `DATA_DIR` to the directory in which you have put the `CSV` files.

# %%
# DATA_DIR = "./../data"
DATA_DIR = os.path.expanduser("~/Downloads/trainingandtestdata/")
training_csv_file = os.path.join(DATA_DIR, 'training.1600000.processed.noemoticon.csv')

# %%
training_csv_file
# Out:
# '/Users/ashutosh_gangwar/Downloads/trainingandtestdata/training.1600000.processed.noemoticon.csv'

# %% [markdown]
# ## A peek at the data

# %%
names = ('polarity', 'id', 'date', 'query', 'author', 'text')
df = pd.read_csv(training_csv_file, encoding='latin1', names=names)

# %%
pd.options.display.max_colwidth = 140  # allow wide columns
df.head()  # show first 5 rows
# Out:
#    polarity          id                          date     query  \
# 0         0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1         0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2         0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3         0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4         0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#             author  \
# 0  _TheSpecialOne_
# 1    scotthamilton
# 2         mattycus
# 3          ElleCTF
# 4           Karoli
#
#                                                                                                                   text
# 0  @switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D
# 1      is upset that he can't update his Facebook by texting it... and might cry as a result  School today also. Blah!
# 2                            @Kenichan I dived many times for the ball. Managed to save 50%  The rest go out of bounds
# 3                                                                      my whole body feels itchy and like its on fire
# 4      @nationwideclass no, it's not behaving at all. i'm mad. why am i here? because I can't see you all over there.

# %%
df.tail()
# Out:
#          polarity          id                          date     query  \
# 1599995         4  2193601966  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599996         4  2193601969  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599997         4  2193601991  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599998         4  2193602064  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599999         4  2193602129  Tue Jun 16 08:40:50 PDT 2009  NO_QUERY
#
#                   author  \
# 1599995  AmandaMarie1028
# 1599996      TheWDBoards
# 1599997           bpbabe
# 1599998     tinydiamondz
# 1599999   RyanTrevMorris
#
#                                                                                    text
# 1599995                        Just woke up. Having no school is the best feeling ever
# 1599996  TheWDB.com - Very cool to hear old Walt interviews!  â« http://blip.fm/~8bmta
# 1599997                       Are you ready for your MoJo Makeover? Ask me for details
# 1599998               Happy 38th Birthday to my boo of alll time!!! Tupac Amaru Shakur
# 1599999                  happy #charitytuesday @theNSPCC @SparksCharity @SpeakingUpH4H

# %%
df['polarity'] = df['polarity'].replace({0: -1, 4: 1})
text = df['text']
target = df['polarity'].values

# %%
print(len(target), len(text))
# Out:
# 1600000 1600000

# %% [markdown]
# ## Train the model
#
# Set 20% of the data aside to test the trained model

# %%
from sklearn.model_selection import train_test_split

text_train, text_validation, target_train, target_validation = (
    train_test_split(text, target, test_size=0.2, random_state=42)
)

# %% [markdown]
# Build a pipeline

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.linear_model import LogisticRegressionCV
from sklearn.pipeline import Pipeline

vectorizer = CountVectorizer(ngram_range=(1, 2), max_features=100000)
feature_selector = SelectKBest(chi2, k=5000)
classifier = LogisticRegressionCV(n_jobs=4)

# %% [markdown]
# This next cell took ~3 minutes to run on my machine

# %%
if os.path.exists('model.pkl'):
    sentiment_pipeline = joblib.load('model.pkl')
else:
    sentiment_pipeline = Pipeline((
        ('v', vectorizer),
        ('f', feature_selector),
        ('c', classifier)
    ))
    sentiment_pipeline.fit(text_train, target_train)
    joblib.dump(sentiment_pipeline, 'model.pkl')

# %% [markdown]
# ## Test the model

# %%
print(sentiment_pipeline.predict(['bad', 'good', "didnt like", "today was a good day", "i hate this product"]))
# Out:
# [-1  1 -1  1 -1]

# %%
for text, target in zip(text_validation[:10], target_validation[:10]):
    print(sentiment_pipeline.predict([text])[0], target, '\t', text)
# Out:
# 1 -1 	 @chrishasboobs AHHH I HOPE YOUR OK!!!
# 1 -1 	 @misstoriblack cool , i have no tweet apps  for my razr 2
# 1 -1 	 @TiannaChaos i know  just family drama. its lame.hey next time u hang out with kim n u guys like have a sleepover or whatever, ill call u
# -1 -1 	 School email won't open  and I have geography stuff on there to revise! *Stupid School* :'(
# 1 -1 	 upper airways problem
# -1 -1 	 Going to miss Pastor's sermon on Faith...
# 1 1 	 on lunch....dj should come eat with me
# -1 -1 	 @piginthepoke oh why are you feeling like that?
# -1 -1 	 gahh noo!peyton needs to live!this is horrible
# 1 1 	 @mrstessyman thank you glad you like it! There is a product review bit on the site  Enjoy knitting it!

# %%
sentiment_pipeline.score(text_validation, target_validation)
# Out:
# 0.799284375

# %% [markdown]
# ## What did the model learn?

# %%
feature_names = sentiment_pipeline.steps[0][1].get_feature_names_out()
feature_names = [feature_names[i] for i in 
                 sentiment_pipeline.steps[1][1].get_support(indices=True)]

def show_most_informative_features(feature_names, clf, n=1000):
    coefs_with_fns = sorted(zip(clf.coef_[0], feature_names))
    top = zip(coefs_with_fns[:n], coefs_with_fns[:-(n + 1):-1])
    for (coef_1, fn_1), (coef_2, fn_2) in top:
        print("\t%.4f\t%-15s\t\t%.4f\t%-15s" % (coef_1, fn_1, coef_2, fn_2))

# %%
show_most_informative_features(feature_names, sentiment_pipeline.steps[2][1], n=500)
# Out:
# 	-3.6187	not happy      		2.7835	no problem
# 	-3.0757	clean me       		2.7460	cannot wait
# 	-3.0033	not looking    		2.3869	smiling
# 	-2.9488	sad            		2.3536	cant wait
# 	-2.7518	not nice       		2.2320	no prob
# 	-2.7422	not cool       		2.1401	nothing wrong
# 	-2.7401	gutted         		2.1333	not bad
# 	-2.7362	disappointing  		2.1120	no worries
# 	-2.7002	no luck        		1.9713	congratulations
# 	-2.6049	sadly          		1.8037	welcome
# 	-2.5782	passed away    		1.7772	musicmonday
# 	-2.5243	not fun        		1.7414	yayyy
# 	-2.4720	inaperfectworld		1.7013	thankyou
# 	-2.4599	rip            		1.6555	smiles
# 	-2.4535	depressed      		1.6331	woooo
# 	-2.4207	poor           		1.6316	smile
# 	-2.4185	bummer         		1.6208	no probs
# 	-2.4121	bummed         		1.5850	proud
# 	-2.3946	depressing     		1.5808	yayy
# 	-2.3801	funeral        		1.5448	thanks
# 	-2.3597	cancelled      		1.5300	amusing
# 	-2.3473	nooooo         		1.5170	blessed
# 	-2.3369	ruined         		1.5100	followfriday
# 	-2.3361	headache       		1.4914	hehehe
# 	-2.3184	boooo          		1.4905	just sayin
# 	-2.2742	hurts          		1.4640	hate hate
# 	-2.2577	missin         		1.4600	yey
# 	-2.2566	unfortunately  		1.4461	laughter
# 	-2.2355	poorly         		1.4363	can wait
# 	-2.2246	heartbroken    		1.4287	congrats
# 	-2.1980	not excited    		1.4249	pleasure
# 	-2.1922	misses         		1.4240	feels good
# 	-2.1899	unfair         		1.4235	heheh
# 	-2.1881	what wrong     		1.4229	whoo
# 	-2.1784	sadness        		1.3900	woohoo
# 	-2.1729	dissapointed   		1.3843	for following
# 	-2.1719	so mean        		1.3798	thank
# 	-2.1675	not good       		1.3703	excellent
# 	-2.1564	heartbreaking  		1.3609	giggle
# 	-2.1447	booo           		1.3496	don forget
# 	-2.1388	noooooo        		1.3456	thumbs up
# 	-2.1340	disappointed   		1.3452	appreciated
# 	-2.1122	migraine       		1.3391	social media
# 	-2.1009	sick           		1.3268	cheers
# 	-2.0994	dreading       		1.3248	grin
# 	-2.0984	homesick       		1.3148	thx
# 	-2.0946	missing        		1.3127	wooooo
# 	-2.0926	unhappy        		1.3093	hihi
# 	-2.0866	air france     		1.3055	peaceful
# 	-2.0776	booooo         		1.3051	loving
# 	-2.0717	not fair       		1.3040	goodsex
# 	-2.0586	upsetting      		1.3021	awesomeness
# 	-2.0491	canceled       		1.3002	relaxed
# 	-2.0475	boohoo         		1.2995	feel free
# 	-2.0419	no fun         		1.2993	my pleasure
# 	-2.0142	not funny      		1.2986	hooray
# 	-2.0070	saddest        		1.2914	sad but
# 	-2.0041	won let        		1.2863	yummm
# 	-1.9998	drop by        		1.2803	glad
# 	-1.9925	cries          		1.2777	fuzzball
# 	-1.9923	fed up         		1.2678	blessings
# 	-1.9908	died           		1.2642	stoked
# 	-1.9783	let down       		1.2589	goood
# 	-1.9633	sucks          		1.2579	teehee
# 	-1.9561	sold out       		1.2565	hehe
# 	-1.9529	not feeling    		1.2496	thankful
# 	-1.9487	toothache      		1.2481	excited
# 	-1.9328	good bye       		1.2420	grateful
# 	-1.9227	iran           		1.2398	sweetest
# 	-1.9173	still no       		1.2371	yaaay
# 	-1.9106	lonely         		1.2370	goooood
# 	-1.9079	meanie         		1.2310	fabulous
# 	-1.9070	sadd           		1.2290	yaay
# 	-1.9039	sux            		1.2254	ftw
# 	-1.9025	cramps         		1.2217	happy
# 	-1.8922	hates          		1.2165	heehee
# 	-1.8857	not coming     		1.2149	heh
# 	-1.8750	tragic         		1.2069	nicely
# 	-1.8745	broke          		1.1918	god is
# 	-1.8648	miss           		1.1903	heya
# 	-1.8607	farrah         		1.1877	np
# 	-1.8541	dontyouhate    		1.1854	yay
# 	-1.8493	hayfever       		1.1836	yumm
# 	-1.8458	unfortunate    		1.1770	heey
# 	-1.8419	not enjoying   		1.1723	inspired
# 	-1.8386	no good        		1.1714	gooood
# 	-1.8340	didn win       		1.1713	yummy
# 	-1.8295	crashes        		1.1693	adorable
# 	-1.8278	taking forever 		1.1656	dont forget
# 	-1.8190	upset          		1.1628	hello
# 	-1.8154	coughing       		1.1595	gotta love
# 	-1.8084	frustrated     		1.1571	quote
# 	-1.8083	devastated     		1.1550	wonderful
# 	-1.8077	noooo          		1.1467	lovin
# 	-1.8072	never got      		1.1417	goodnight
# 	-1.8035	stinks         		1.1415	honored
# 	-1.8016	ughhh          		1.1394	blessing
# 	-1.7943	alas           		1.1369	bed night
# 	-1.7881	injured        		1.1353	don mind
# 	-1.7866	there goes     		1.1337	goodluck
# 	-1.7856	condolences    		1.1253	sick but
# 	-1.7813	whats wrong    		1.1237	found you
# 	-1.7768	horrible       		1.1233	be sad
# 	-1.7740	struggling     		1.1229	too funny
# 	-1.7739	wouldn let     		1.1214	handy
# 	-1.7711	bnp            		1.1180	tnx
# 	-1.7666	hiccups        		1.1075	thanx
# 	-1.7642	crying         		1.1067	gracias
# 	-1.7618	wont let       		1.1063	hugh
# 	-1.7584	hurting        		1.1011	hee
# 	-1.7568	summer school  		1.0992	woot
# 	-1.7548	fathers day    		1.0944	reward
# 	-1.7511	ftl            		1.0930	howdy
# 	-1.7461	saddened       		1.0927	about time
# 	-1.7414	won work       		1.0924	pleased
# 	-1.7226	answer me      		1.0897	yessss
# 	-1.7206	no new         		1.0894	sad sad
# 	-1.7180	shame          		1.0894	rocks
# 	-1.7102	infection      		1.0886	praise
# 	-1.7081	disappeared    		1.0863	awesome
# 	-1.7075	is down        		1.0861	at last
# 	-1.7072	wishin         		1.0835	opinion
# 	-1.7062	pity           		1.0792	crack me
# 	-1.7037	not ready      		1.0706	hiya
# 	-1.6903	miserable      		1.0649	w00t
# 	-1.6879	awful          		1.0589	knew you
# 	-1.6827	pakcricket     		1.0546	pumped
# 	-1.6735	not very       		1.0537	we come
# 	-1.6730	feel well      		1.0517	you want
# 	-1.6712	broken         		1.0479	shine
# 	-1.6711	disappointment 		1.0475	yum
# 	-1.6671	sucky          		1.0460	enjoying
# 	-1.6610	without me     		1.0341	ttyl
# 	-1.6513	ache           		1.0307	why thank
# 	-1.6499	yucky          		1.0306	aww thanks
# 	-1.6454	fml            		1.0306	alike
# 	-1.6438	failed         		1.0293	awsome
# 	-1.6437	not liking     		1.0273	tetris
# 	-1.6399	father day     		1.0257	relaxing
# 	-1.6357	ugh            		1.0240	hilarious
# 	-1.6305	noes           		1.0239	learning how
# 	-1.6237	huhuhu         		1.0222	wooo
# 	-1.6204	hmph           		1.0206	bliss
# 	-1.6193	an end         		1.0180	loves
# 	-1.6190	ughhhh         		1.0178	hola
# 	-1.6187	why must       		1.0136	days until
# 	-1.6162	nooooooo       		1.0134	handsome
# 	-1.6106	downside       		1.0103	cute
# 	-1.6089	jury duty      		1.0102	tommcfly http
# 	-1.6089	coursework     		1.0101	nice work
# 	-1.6061	happy father   		1.0076	amazing
# 	-1.5896	gloomy         		1.0044	laughing
# 	-1.5830	isn good       		1.0038	it fun
# 	-1.5800	iranelection   		1.0035	you wanna
# 	-1.5792	screwed        		1.0011	familiar
# 	-1.5752	sadface        		1.0006	thnx
# 	-1.5720	hate           		0.9998	goodmorning
# 	-1.5701	terrible       		0.9995	curious
# 	-1.5672	bad times      		0.9988	multiply
# 	-1.5634	the er         		0.9981	stay tuned
# 	-1.5626	damnit         		0.9955	cool
# 	-1.5586	never reply    		0.9947	ugh hate
# 	-1.5567	neglected      		0.9898	made my
# 	-1.5531	sunburned      		0.9863	try it
# 	-1.5519	stolen         		0.9836	brilliant
# 	-1.5477	ouch           		0.9833	greetings
# 	-1.5442	closed         		0.9823	adore
# 	-1.5413	swollen        		0.9813	cutie
# 	-1.5406	dammit         		0.9799	positive
# 	-1.5367	tear           		0.9792	woo
# 	-1.5363	shattered      		0.9759	happiness
# 	-1.5349	shitty         		0.9725	17 again
# 	-1.5311	not feelin     		0.9701	power of
# 	-1.5298	frustrating    		0.9693	myweakness
# 	-1.5238	fail           		0.9685	holla
# 	-1.5209	some reason    		0.9678	just wanted
# 	-1.5206	rained         		0.9655	fantastic
# 	-1.5190	unfortunatly   		0.9652	heyyy
# 	-1.5188	need hug       		0.9621	funniest
# 	-1.5179	argh           		0.9609	unique
# 	-1.5159	crappy         		0.9576	enjoy
# 	-1.5153	suffering      		0.9561	better now
# 	-1.5151	wheres         		0.9560	good work
# 	-1.5145	3gs            		0.9546	the poor
# 	-1.5123	but but        		0.9542	back later
# 	-1.5108	mms            		0.9533	is fun
# 	-1.5072	bad luck       		0.9368	prefer
# 	-1.5063	loosing        		0.9366	luck
# 	-1.5037	stressed       		0.9357	neat
# 	-1.4985	cry            		0.9338	mmmm
# 	-1.4981	forgot my      		0.9329	beauty
# 	-1.4973	humid          		0.9262	iamdiddy
# 	-1.4972	having trouble 		0.9235	mmmmm
# 	-1.4967	spilled        		0.9214	heyy
# 	-1.4947	not well       		0.9203	sure thing
# 	-1.4938	why won        		0.9202	ahaha
# 	-1.4888	ashamed        		0.9187	lovely
# 	-1.4873	losing         		0.9142	bom
# 	-1.4851	suspended      		0.9086	lovee
# 	-1.4811	rest in        		0.9076	sweet
# 	-1.4738	crushed        		0.9051	love being
# 	-1.4728	delayed        		0.9016	bored bored
# 	-1.4697	how come       		0.9000	inspiring
# 	-1.4687	won see        		0.8996	helps
# 	-1.4631	boo            		0.8975	you might
# 	-1.4618	worried        		0.8934	funny
# 	-1.4618	bad day        		0.8931	ty
# 	-1.4607	disabled       		0.8917	compliment
# 	-1.4599	tears          		0.8887	relax
# 	-1.4590	failing        		0.8881	lets
# 	-1.4579	sob            		0.8863	always good
# 	-1.4571	nooo           		0.8853	in case
# 	-1.4570	cannot         		0.8824	how sweet
# 	-1.4525	rubbish        		0.8800	entertaining
# 	-1.4513	worst          		0.8798	perfect
# 	-1.4507	no1            		0.8749	of course
# 	-1.4502	to reality     		0.8748	fly with
# 	-1.4497	noooooooooo    		0.8732	productive
# 	-1.4486	disgusting     		0.8716	even better
# 	-1.4467	never see      		0.8715	like plan
# 	-1.4455	bugger         		0.8706	gorgeous
# 	-1.4450	why can        		0.8683	just need
# 	-1.4445	gotta wait     		0.8670	thanking
# 	-1.4388	ignored        		0.8625	nice
# 	-1.4362	boooooo        		0.8606	giveaway
# 	-1.4357	missed         		0.8581	hell yeah
# 	-1.4350	not found      		0.8578	www
# 	-1.4340	huhu           		0.8541	hahaha
# 	-1.4305	too fast       		0.8540	feedback
# 	-1.4282	no fair        		0.8536	re good
# 	-1.4252	leaves         		0.8513	me laugh
# 	-1.4223	rainin         		0.8509	kindly
# 	-1.4201	cried          		0.8496	bom dia
# 	-1.4198	not showing    		0.8466	was sick
# 	-1.4179	dies           		0.8427	go girl
# 	-1.4156	divorce        		0.8426	celebration
# 	-1.4133	goodbye        		0.8410	just wondering
# 	-1.4074	ripped         		0.8393	clever
# 	-1.4017	yuck           		0.8371	its great
# 	-1.4001	oh noes        		0.8370	good evening
# 	-1.3993	dislike        		0.8366	join me
# 	-1.3976	regents        		0.8353	humor
# 	-1.3905	unloved        		0.8348	aw thanks
# 	-1.3901	scratched      		0.8346	watch out
# 	-1.3898	throwing up    		0.8266	surprised
# 	-1.3897	grrr           		0.8258	talented
# 	-1.3877	something wrong		0.8247	sleep tight
# 	-1.3860	lost my        		0.8247	ha
# 	-1.3835	we lost        		0.8242	genius
# 	-1.3826	vet            		0.8238	peace
# 	-1.3826	happy fathers  		0.8212	the lord
# 	-1.3760	gross          		0.8203	right back
# 	-1.3728	breaks my      		0.8201	went well
# 	-1.3706	hating         		0.8180	laughs
# 	-1.3704	cancel         		0.8180	everyone should
# 	-1.3703	disconnected   		0.8130	certainly
# 	-1.3693	sadder         		0.8125	yesss
# 	-1.3692	crashed        		0.8121	useful
# 	-1.3674	painful        		0.8033	in mind
# 	-1.3670	bye to         		0.8029	success
# 	-1.3632	ate all        		0.8025	here come
# 	-1.3618	surgery        		0.8015	hi
# 	-1.3611	hasnt          		0.8011	realhughjackman
# 	-1.3610	hurt           		0.8004	conversation
# 	-1.3604	burned         		0.7994	rockin
# 	-1.3589	was hoping     		0.7969	anytime
# 	-1.3564	ick            		0.7935	sad just
# 	-1.3554	but live       		0.7924	how are
# 	-1.3553	urgh           		0.7917	loves it
# 	-1.3547	whyyyy         		0.7904	worth it
# 	-1.3528	stressing      		0.7890	cutest
# 	-1.3525	nightmare      		0.7885	whoop
# 	-1.3519	nowhere to     		0.7884	coming soon
# 	-1.3513	down today     		0.7882	chatting
# 	-1.3505	sry            		0.7872	aha
# 	-1.3495	doesn look     		0.7869	rocking
# 	-1.3473	hacked         		0.7866	get sick
# 	-1.3470	torn           		0.7856	celebrating
# 	-1.3465	laid off       		0.7830	great news
# 	-1.3454	ignoring me    		0.7819	chillin
# 	-1.3444	not here       		0.7780	sweet dreams
# 	-1.3431	destroyed      		0.7775	haha
# 	-1.3413	ruining        		0.7774	let get
# 	-1.3408	cant           		0.7767	colorblindfish
# 	-1.3377	bleeding       		0.7766	sweetheart
# 	-1.3377	leaving me     		0.7753	just thought
# 	-1.3371	expired        		0.7750	come join
# 	-1.3367	goodbyes       		0.7730	beautiful
# 	-1.3364	won come       		0.7720	interesting
# 	-1.3350	no go          		0.7717	dm me
# 	-1.3343	bad news       		0.7715	love this
# 	-1.3324	blows          		0.7695	classic
# 	-1.3272	not playing    		0.7674	fresh
# 	-1.3253	stranded       		0.7659	of fun
# 	-1.3175	ouchie         		0.7644	chilling
# 	-1.3168	dull           		0.7639	recommendation
# 	-1.3155	annoyed        		0.7634	enjoyed
# 	-1.3155	deleted        		0.7631	very happy
# 	-1.3131	isn working    		0.7628	lakers
# 	-1.3128	scared         		0.7615	recommend
# 	-1.3123	sigh           		0.7609	new favorite
# 	-1.3120	stung          		0.7573	don worry
# 	-1.3117	throw up       		0.7547	sooo excited
# 	-1.3091	burnt my       		0.7531	featured
# 	-1.3082	not getting    		0.7520	much better
# 	-1.3078	cant find      		0.7510	ugh im
# 	-1.3070	wishing could  		0.7503	mmm
# 	-1.3061	don like       		0.7475	rules
# 	-1.3057	neda           		0.7453	being sick
# 	-1.3035	drained        		0.7450	greatest
# 	-1.2978	not available  		0.7429	quotes
# 	-1.2963	still waiting  		0.7406	tasty
# 	-1.2948	allergic       		0.7394	mariahcarey
# 	-1.2942	sucked         		0.7389	finally
# 	-1.2877	sorry          		0.7326	great to
# 	-1.2858	froze          		0.7324	that right
# 	-1.2815	sore           		0.7281	liked it
# 	-1.2800	but me         		0.7274	my dear
# 	-1.2790	no sun         		0.7253	hahahaha
# 	-1.2785	ran over       		0.7249	100 followers
# 	-1.2783	sniff          		0.7222	exciting
# 	-1.2780	last episode   		0.7217	tomfelton
# 	-1.2720	why does       		0.7209	love
# 	-1.2715	stuck          		0.7206	http blip
# 	-1.2693	is leaving     		0.7204	tweeters
# 	-1.2688	heartburn      		0.7200	hah
# 	-1.2682	can find       		0.7185	challenge
# 	-1.2682	sunburnt       		0.7165	great week
# 	-1.2672	poisoning      		0.7155	rain rain
# 	-1.2670	by myself      		0.7111	nighty
# 	-1.2648	was looking    		0.7099	tune
# 	-1.2637	freezing       		0.7097	sang
# 	-1.2625	getting old    		0.7086	remember to
# 	-1.2623	postponed      		0.7074	140
# 	-1.2588	lost           		0.7058	bride
# 	-1.2584	allergies      		0.7054	dont worry
# 	-1.2582	cloudy         		0.7030	sick of
# 	-1.2556	blocked        		0.7015	tweet was
# 	-1.2551	horrid         		0.6994	keep the
# 	-1.2542	why did        		0.6985	dig
# 	-1.2533	being mean     		0.6981	smart
# 	-1.2526	depression     		0.6969	mrtweet
# 	-1.2520	last show      		0.6950	the follow
# 	-1.2517	attacked       		0.6943	have great
# 	-1.2485	didn get       		0.6937	good choice
# 	-1.2483	cruel          		0.6931	tweeties
# 	-1.2482	trackle        		0.6930	ya tomorrow
# 	-1.2462	suck           		0.6914	youngq
# 	-1.2455	need new       		0.6914	case you
# 	-1.2436	so mad         		0.6909	and eating
# 	-1.2433	fell           		0.6906	am happy
# 	-1.2427	anxiety        		0.6891	follow
# 	-1.2422	arghh          		0.6882	adventure
# 	-1.2417	none           		0.6880	twitterverse
# 	-1.2413	so sorry       		0.6870	great job
# 	-1.2389	worrying       		0.6868	twittering
# 	-1.2382	saddens        		0.6862	he he
# 	-1.2378	not having     		0.6842	sad and
# 	-1.2365	mourning       		0.6842	allen
# 	-1.2337	be missed      		0.6836	at http
# 	-1.2336	arent          		0.6834	great
# 	-1.2308	wish           		0.6828	good
# 	-1.2296	expensive      		0.6819	it great
# 	-1.2292	ewww           		0.6817	to ya
# 	-1.2288	fever          		0.6811	its good
# 	-1.2259	wishing        		0.6794	hi there
# 	-1.2233	error          		0.6784	worry
# 	-1.2231	oh no          		0.6768	blast
# 	-1.2216	grr            		0.6758	much fun
# 	-1.2210	what happened  		0.6753	style
# 	-1.2202	feel for       		0.6741	to hurt
# 	-1.2168	unable         		0.6739	retweet
# 	-1.2142	refuses        		0.6734	joining
# 	-1.2134	hit by         		0.6728	creative
# 	-1.2129	itchy          		0.6724	check this
# 	-1.2126	all alone      		0.6722	strawberry
# 	-1.2118	pathetic       		0.6716	you too
# 	-1.2101	couldn make    		0.6714	depends
# 	-1.2099	feeling ill    		0.6713	long as
# 	-1.2080	running out    		0.6702	surprise
# 	-1.2078	ughh           		0.6697	diversity
# 	-1.2074	be long        		0.6683	got my
# 	-1.2072	to early       		0.6677	have nice
# 	-1.2044	should ve      		0.6669	love my
# 	-1.2042	accident       		0.6668	perhaps
# 	-1.2031	would but      		0.6655	glad could
# 	-1.1982	oh dear        		0.6648	happy sunday
# 	-1.1980	never gonna    		0.6643	heaven
# 	-1.1965	no friends     		0.6631	indeed
# 	-1.1963	problem is     		0.6614	hey
# 	-1.1960	arg            		0.6600	the ff
# 	-1.1959	no money       		0.6592	some fun
# 	-1.1943	wish was       		0.6584	that cute
# 	-1.1925	where did      		0.6574	has great
# 	-1.1925	icky           		0.6556	just ordered
# 	-1.1925	iphone update  		0.6552	listening
# 	-1.1914	where is       		0.6542	all is
# 	-1.1913	dangit         		0.6541	coolest
# 	-1.1905	wishing was    		0.6539	worship
# 	-1.1899	hit my         		0.6533	happy mother
# 	-1.1899	feel ill       		0.6522	doing great
# 	-1.1895	bites          		0.6519	incredible
# 	-1.1870	when will      		0.6510	rocked
# 	-1.1868	30 tag         		0.6502	awww thanks
# 	-1.1853	got cold       		0.6499	recommendations
# 	-1.1848	it says        		0.6492	½ï
# 	-1.1847	left my        		0.6478	geek
# 	-1.1839	coulda         		0.6475	hahah
# 	-1.1832	storming       		0.6454	got twitter
# 	-1.1803	uncomfortable  		0.6450	love it
# 	-1.1769	suicide        		0.6444	too cute
# 	-1.1753	banned         		0.6435	lyrics
# 	-1.1752	noooooooo      		0.6424	sexy
# 	-1.1750	burnt          		0.6411	added
# 	-1.1729	sicky          		0.6400	ð¼ð
# 	-1.1714	dont like      		0.6378	now following
# 	-1.1695	smh            		0.6361	so exciting
# 	-1.1687	grounded       		0.6360	nothing like
# 	-1.1661	didnt get      		0.6345	content
# 	-1.1645	never going    		0.6344	nerd
# 	-1.1640	blister        		0.6340	join us
# 	-1.1636	doesn work     		0.6337	appreciate
# 	-1.1619	bronchitis     		0.6331	plenty
# 	-1.1589	wishes         		0.6329	hello there
# 	-1.1584	wont           		0.6320	hope to
# 	-1.1583	left out       		0.6318	yes
# 	-1.1575	isnt           		0.6310	sir
# 	-1.1573	noo            		0.6307	delicious
# 	-1.1564	couldnt        		0.6303	all good
# 	-1.1553	boring         		0.6296	chill
# 	-1.1549	bit my         		0.6292	are great
# 	-1.1529	wimbledon      		0.6285	yup
# 	-1.1524	dentist        		0.6284	take look
# 	-1.1479	isnt working   		0.6273	you really
# 	-1.1476	sunburn        		0.6268	tunes
# 	-1.1473	wana           		0.6260	homemade
# 	-1.1463	heard from     		0.6236	sick and
# 	-1.1445	not able       		0.6225	fell asleep
# 	-1.1433	is broken      		0.6222	be your
# 	-1.1433	grrrr          		0.6215	be sick
# 	-1.1412	going away     		0.6203	you need
# 	-1.1395	blew           		0.6192	aplusk
# 	-1.1394	not working    		0.6173	oh and
# 	-1.1392	starving       		0.6173	is loving
# 	-1.1384	fathers        		0.6173	your work
# 	-1.1383	aches          		0.6164	may the
# 	-1.1381	not there      		0.6144	really cute
# 	-1.1357	twitter won    		0.6142	ask
# 	-1.1339	to wait        		0.6132	tweeps
# 	-1.1335	our last       		0.6123	all time
# 	-1.1319	just when      		0.6120	keep up
# 	-1.1303	not impressed  		0.6113	shall
# 	-1.1298	sprained       		0.6110	for asking
# 	-1.1293	ran out        		0.6098	check them
# 	-1.1292	oh god         		0.6085	have wonderful
# 	-1.1259	throat         		0.6075	shoutout
# 	-1.1253	but no         		0.6074	is listening
# 	-1.1236	so confused    		0.6071	fine
# 	-1.1222	aww man        		0.6053	spreading
# 	-1.1210	mosquito       		0.6048	is excited
# 	-1.1209	bleh           		0.6034	had fun
# 	-1.1207	eff            		0.6019	billyraycyrus
# 	-1.1199	jailbreak      		0.6015	is perfect
# 	-1.1178	insomnia       		0.6010	loves the
# 	-1.1168	in work        		0.6008	museum
# 	-1.1147	oww            		0.5996	deserved
# 	-1.1147	raining        		0.5989	bed good
# 	-1.1136	almost over    		0.5971	aww thank
# 	-1.1126	eww            		0.5967	special
# 	-1.1117	wtf            		0.5959	all about
# 	-1.1090	like shit      		0.5949	just for
# 	-1.1086	never answer   		0.5934	is good
# 	-1.1072	wanted         		0.5908	is happy
# 	-1.1064	asthma         		0.5906	very cute
# 	-1.1037	bah            		0.5905	to know
# 	-1.1037	sniffle        		0.5902	check it
# 	-1.1021	shoulda        		0.5901	rock
# 	-1.1020	doesn like     		0.5895	fab
# 	-1.1019	failure        		0.5890	fave
# 	-1.1007	costs          		0.5882	poor guy
# 	-1.0997	pissed         		0.5870	loved it
# 	-1.0995	badly          		0.5863	playlist
# 	-1.0974	is acting      		0.5860	we can
# 	-1.0957	david carradine		0.5831	you later
# 	-1.0952	bed alone      		0.5825	twilight
# 	-1.0942	same without   		0.5822	well worth
# 	-1.0918	blisters       		0.5819	forward
# 	-1.0911	got hit        		0.5814	definitely
# 	-1.0895	woe            		0.5809	good weekend
# 	-1.0893	me anymore     		0.5809	keep it
# 	-1.0884	good thanks    		0.5806	got new
# 	-1.0881	accidentally   		0.5802	hey there
# 	-1.0865	messed         		0.5798	let see
# 	-1.0862	wishes he      		0.5787	song of
# 	-1.0855	acting up      		0.5783	watching
# 	-1.0850	damaged        		0.5778	how love
# 	-1.0836	sytycd         		0.5775	night everyone
# 	-1.0827	removed        		0.5775	morning how
# 	-1.0821	why is         		0.5771	bing
# 	-1.0817	much pain      		0.5762	laugh
