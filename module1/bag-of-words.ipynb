# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # A simple sentiment prototype

# %%
import os  # manipulate paths
import pandas as pd  # SQL-like operations and convenience functions
import joblib  # save and load models

# %% [markdown]
# Download the Sentiment140 data from [their website](http://help.sentiment140.com/for-students) or directly from [Standford site](http://cs.stanford.edu/people/alecmgo/trainingandtestdata.zip) and set `DATA_DIR` to the directory in which you have put the `CSV` files.

# %%
DATA_DIR = "./../data"
training_csv_file = os.path.join(DATA_DIR, 'training.1600000.processed.noemoticon.csv')

# %%
training_csv_file
# Out:
# './../data/training.1600000.processed.noemoticon.csv'

# %% [markdown]
# ## A peek at the data

# %%
names = ('polarity', 'id', 'date', 'query', 'author', 'text')
df = pd.read_csv(training_csv_file, encoding='latin1', names=names)

# %%
pd.options.display.max_colwidth = 140  # allow wide columns
df.head()  # show first 5 rows
# Out:
#    polarity          id                          date     query  \
# 0         0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1         0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2         0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3         0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4         0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#             author  \
# 0  _TheSpecialOne_
# 1    scotthamilton
# 2         mattycus
# 3          ElleCTF
# 4           Karoli
#
#                                                                                                                   text
# 0  @switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D
# 1      is upset that he can't update his Facebook by texting it... and might cry as a result  School today also. Blah!
# 2                            @Kenichan I dived many times for the ball. Managed to save 50%  The rest go out of bounds
# 3                                                                      my whole body feels itchy and like its on fire
# 4      @nationwideclass no, it's not behaving at all. i'm mad. why am i here? because I can't see you all over there.

# %%
df.tail()
# Out:
#          polarity          id                          date     query  \
# 1599995         4  2193601966  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599996         4  2193601969  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599997         4  2193601991  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599998         4  2193602064  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599999         4  2193602129  Tue Jun 16 08:40:50 PDT 2009  NO_QUERY
#
#                   author  \
# 1599995  AmandaMarie1028
# 1599996      TheWDBoards
# 1599997           bpbabe
# 1599998     tinydiamondz
# 1599999   RyanTrevMorris
#
#                                                                                    text
# 1599995                        Just woke up. Having no school is the best feeling ever
# 1599996  TheWDB.com - Very cool to hear old Walt interviews!  â« http://blip.fm/~8bmta
# 1599997                       Are you ready for your MoJo Makeover? Ask me for details
# 1599998               Happy 38th Birthday to my boo of alll time!!! Tupac Amaru Shakur
# 1599999                  happy #charitytuesday @theNSPCC @SparksCharity @SpeakingUpH4H

# %%
df['polarity'].replace({0: -1, 4: 1}, inplace=True)
text = df['text']
target = df['polarity'].values

# %%
print(len(target), len(text))
# Out:
# 1600000 1600000

# %% [markdown]
# ## Train the model
#
# Set 20% of the data aside to test the trained model

# %%
from sklearn.cross_validation import train_test_split

text_train, text_validation, target_train, target_validation = (
    train_test_split(text, target, test_size=0.2, random_state=42)
)
# Out:
# /home/piyush/Piyush/study/anthill/anthill/lib/python3.5/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# Build a pipeline

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.linear_model import LogisticRegressionCV
from sklearn.pipeline import Pipeline

vectorizer = CountVectorizer(ngram_range=(1, 2), max_features=100000)
feature_selector = SelectKBest(chi2, k=5000)
classifier = LogisticRegressionCV(n_jobs=4)

# %% [markdown]
# This next cell took ~3 minutes to run on my machine

# %%
if os.path.exists('model.pkl'):
    sentiment_pipeline = joblib.load('model.pkl')
else:
    sentiment_pipeline = Pipeline((
        ('v', vectorizer),
        ('f', feature_selector),
        ('c', classifier)
    ))
    sentiment_pipeline.fit(text_train, target_train)
    joblib.dump(sentiment_pipeline, 'model.pkl');

# %% [markdown]
# ## Test the model

# %%
print(sentiment_pipeline.predict(['bad', 'good', "didnt like", "today was a good day", "i hate this product"]))
# Out:
# [-1  1 -1  1 -1]

# %%
for text, target in zip(text_validation[:10], target_validation[:10]):
    print(sentiment_pipeline.predict([text])[0], target, '\t', text)
# Out:
# 1 -1 	 @chrishasboobs AHHH I HOPE YOUR OK!!!
# 1 -1 	 @misstoriblack cool , i have no tweet apps  for my razr 2
# 1 -1 	 @TiannaChaos i know  just family drama. its lame.hey next time u hang out with kim n u guys like have a sleepover or whatever, ill call u
# -1 -1 	 School email won't open  and I have geography stuff on there to revise! *Stupid School* :'(
# 1 -1 	 upper airways problem
# -1 -1 	 Going to miss Pastor's sermon on Faith...
# 1 1 	 on lunch....dj should come eat with me
# -1 -1 	 @piginthepoke oh why are you feeling like that?
# -1 -1 	 gahh noo!peyton needs to live!this is horrible
# 1 1 	 @mrstessyman thank you glad you like it! There is a product review bit on the site  Enjoy knitting it!

# %%
sentiment_pipeline.score(text_validation, target_validation)
# Out:
# 0.799446875

# %% [markdown]
# ## What did the model learn?

# %%
feature_names = sentiment_pipeline.steps[0][1].get_feature_names()
feature_names = [feature_names[i] for i in 
                 sentiment_pipeline.steps[1][1].get_support(indices=True)]

def show_most_informative_features(feature_names, clf, n=1000):
    coefs_with_fns = sorted(zip(clf.coef_[0], feature_names))
    top = zip(coefs_with_fns[:n], coefs_with_fns[:-(n + 1):-1])
    for (coef_1, fn_1), (coef_2, fn_2) in top:
        print("\t%.4f\t%-15s\t\t%.4f\t%-15s" % (coef_1, fn_1, coef_2, fn_2))

# %%
show_most_informative_features(feature_names, sentiment_pipeline.steps[2][1], n=500)
# Out:
# 	-3.4623	not happy      		2.6856	no problem
# 	-3.2877	clean me       		2.6487	no worries
# 	-2.9376	inaperfectworld		2.5492	cannot wait
# 	-2.9264	not looking    		2.3162	cant wait
# 	-2.9099	sad            		2.2833	no prob
# 	-2.8643	passed away    		2.2418	smiling
# 	-2.6961	sadly          		2.1893	nothing wrong
# 	-2.6466	gutted         		2.1225	not bad
# 	-2.6249	not nice       		2.0663	sad sad
# 	-2.6216	not cool       		1.9272	congratulations
# 	-2.5890	disappointing  		1.8083	fuzzball
# 	-2.5887	no luck        		1.7812	no probs
# 	-2.5095	sadd           		1.7776	welcome
# 	-2.5094	heartbreaking  		1.7284	musicmonday
# 	-2.4801	heartbroken    		1.7241	hate hate
# 	-2.4493	boohoo         		1.6611	smile
# 	-2.4328	rip            		1.6569	yayyy
# 	-2.4306	dontyouhate    		1.6282	thankyou
# 	-2.4099	poor           		1.6233	woooo
# 	-2.4060	not fun        		1.5990	just sayin
# 	-2.3995	bummer         		1.5867	smiles
# 	-2.3805	depressed      		1.5736	heheh
# 	-2.3527	bummed         		1.5723	proud
# 	-2.3449	cancelled      		1.5599	followfriday
# 	-2.3229	depressing     		1.5589	laughter
# 	-2.3178	unfortunately  		1.5532	gracias
# 	-1.6528	heartburn      		0.9969	aww thanks
# 	-1.6511	pity           		0.9967	pumped
# 	-1.6429	won see        		0.9966	made my
# 	-1.6397	not showing    		0.9954	the poor
# 	-1.6390	ignoring me    		0.9939	power of
# 	-1.6375	stung          		0.9929	thanking
# 	-1.6365	terrible       		0.9913	wooo
# 	-1.6324	neglected      		0.9891	cool
# 	-1.6307	not very       		0.9890	awsome
# 	-1.6297	bronchitis     		0.9855	days until
# 	-1.6291	ouch           		0.9837	like plan
# 	-1.6290	yucky          		0.9823	loves
# 	-1.6224	not ready      		0.9812	ttyl
# 	-1.6205	need hug       		0.9799	curious
# 	-1.6200	3gs            		0.9787	glad could
# 	-1.6183	ache           		0.9767	enjoy
# 	-1.6160	miserable      		0.9737	bliss
# 	-1.6139	answer me      		0.9732	multiply
# 	-1.6116	feel ill       		0.9721	handsome
# 	-1.6093	stranded       		0.9699	unique
# 	-1.6071	closed         		0.9688	familiar
# 	-1.6069	disappeared    		0.9678	ugh im
# 	-1.6037	disconnected   		0.9669	cutest
# 	-1.5956	without me     		0.9649	thnx
# 	-1.5952	noes           		0.9615	woo
# 	-1.5935	infection      		0.9596	it fun
# 	-1.5873	hate           		0.9572	happiness
# 	-1.5856	sucky          		0.9550	just wanted
# 	-1.5852	down today     		0.9535	try it
# 	-1.5830	ran over       		0.9489	you wanna
# 	-1.5739	the er         		0.9452	prefer
# 	-1.5715	loosing        		0.9430	new favorite
# 	-1.5660	goodbyes       		0.9429	inspiring
# 	-1.5652	bed alone      		0.9427	mmmm
# 	-1.5630	mms            		0.9424	adore
# 	-1.5587	bad times      		0.9402	sweet
# 	-1.5536	ick            		0.9375	better now
# 	-1.5534	but but        		0.9348	good work
# 	-1.5517	gotta wait     		0.9340	luck
# 	-1.5421	not available  		0.9330	sleep tight
# 	-1.5407	twitter won    		0.9318	aw thanks
# 	-1.5407	screwed        		0.9311	myweakness
# 	-1.5376	no fair        		0.9295	lovely
# 	-1.5354	losing         		0.9244	cutie
# 	-1.5348	saddens        		0.9181	relax
# 	-1.5314	you thank      		0.9151	productive
# 	-1.5311	not well       		0.9140	17 again
# 	-1.5296	coursework     		0.9134	ahaha
# 	-1.5273	dammit         		0.9124	funny
# 	-1.5258	having trouble 		0.9120	helps
# 	-1.5256	argh           		0.9113	is fun
# 	-1.5230	crappy         		0.9103	holla
# 	-1.5228	dangit         		0.9100	beauty
# 	-1.5225	rest in        		0.9082	heyyy
# 	-1.5222	never answer   		0.9057	everyone should
# 	-1.5201	an end         		0.9047	back later
# 	-1.5194	suffering      		0.9005	love being
# 	-1.5134	gloomy         		0.8967	ya tomorrow
# 	-1.5129	leaving me     		0.8949	heyy
# 	-1.5128	but live       		0.8893	bored bored
# 	-1.5104	iranelection   		0.8881	just need
# 	-1.5094	shitty         		0.8877	sooo excited
# 	-1.5053	father day     		0.8831	mmmmm
# 	-1.5052	worried        		0.8822	that cute
# 	-1.5043	got cold       		0.8797	compliment
# 	-1.4969	spilled        		0.8783	ty
# 	-1.4968	never see      		0.8767	gorgeous
# 	-1.4942	tear           		0.8765	neat
# 	-1.4918	isnt working   		0.8762	its great
# 	-1.4909	scratched      		0.8733	you might
# 	-1.4870	not playing    		0.8723	iamdiddy
# 	-1.4866	to reality     		0.8703	was sick
# 	-1.4840	sicky          		0.8697	hahaha
# 	-1.4833	damnit         		0.8632	www
# 	-1.4827	sunburned      		0.8618	lets
# 	-1.4806	some reason    		0.8543	perfect
# 	-1.4760	swollen        		0.8541	bom
# 	-1.4711	fail           		0.8531	great news
# 	-1.4675	tears          		0.8522	good evening
# 	-1.4652	cried          		0.8520	lovee
# 	-1.4632	iphone update  		0.8504	nice
# 	-1.4629	being mean     		0.8493	of course
# 	-1.4625	regents        		0.8482	always good
# 	-1.4623	stolen         		0.8481	great meeting
# 	-1.4617	noooooooo      		0.8473	loves it
# 	-1.4612	burnt my       		0.8446	fly with
# 	-1.4571	expired        		0.8441	hurts like
# 	-1.4531	rained         		0.8409	entertaining
# 	-1.4514	nooo           		0.8286	giveaway
# 	-1.4507	stressed       		0.8282	join me
# 	-1.4486	frustrating    		0.8219	surprised
# 	-1.4473	shattered      		0.8200	feedback
# 	-1.4473	no1            		0.8193	good choice
# 	-1.4445	how come       		0.8174	humor
# 	-1.4434	goodbye        		0.8169	ha
# 	-1.4411	forgot my      		0.8151	mrtweet
# 	-1.4410	owie           		0.8131	in case
# 	-1.4347	humid          		0.8126	me laugh
# 	-1.4336	crushed        		0.8121	anytime
# 	-1.4287	wheres         		0.8108	just wondering
# 	-1.4279	cry            		0.8093	featured
# 	-1.4270	froze          		0.8090	hello there
# 	-1.4264	wishing could  		0.8089	here come
# 	-1.4215	divorce        		0.8079	even better
# 	-1.4208	but nobody     		0.8048	fresh
# 	-1.4205	delayed        		0.8032	nighty
# 	-1.4202	boo            		0.8019	recommendation
# 	-1.4200	bad day        		0.8007	certainly
# 	-1.4197	rubbish        		0.7976	went well
# 	-1.4192	no sun         		0.7973	aha
# 	-1.4117	30 tag         		0.7965	hi
# 	-1.4114	suspended      		0.7963	success
# 	-1.4103	woe            		0.7954	ð¼ð
# 	-1.4094	missed         		0.7925	peace
# 	-1.4083	sob            		0.7909	celebration
# 	-1.4081	drained        		0.7892	coolest
# 	-1.4040	no go          		0.7890	hell yeah
# 	-1.4035	much pain      		0.7869	laughs
# 	-1.4030	huhu           		0.7854	watch out
# 	-1.4011	why can        		0.7843	100 followers
# 	-1.4008	arghh          		0.7833	great week
# 	-1.3970	ashamed        		0.7830	conversation
# 	-1.3934	sniffle        		0.7828	enjoyed
# 	-1.3931	no word        		0.7807	chillin
# 	-1.3905	cannot         		0.7807	chatting
# 	-1.3899	something wrong		0.7803	talented
# 	-1.3893	we lost        		0.7796	love this
# 	-1.3878	not able       		0.7788	how are
# 	-1.3870	torn           		0.7786	http blip
# 	-1.3850	bit my         		0.7774	clever
# 	-1.3849	failing        		0.7772	case you
# 	-1.3840	ignored        		0.7761	genius
# 	-1.3830	arg            		0.7759	yesss
# 	-1.3821	really ill     		0.7757	much better
# 	-1.3808	vet            		0.7746	headache and
# 	-1.3797	worst          		0.7738	get sick
# 	-1.3770	grrrrrr        		0.7734	your thinking
# 	-1.3755	leaves         		0.7730	chilling
# 	-1.3731	lost my        		0.7718	haha
# 	-1.3692	grrr           		0.7715	useful
# 	-1.3667	bugger         		0.7713	sweet dreams
# 	-1.3656	mourning       		0.7703	appreciate that
# 	-1.3643	disgusting     		0.7702	worth it
# 	-1.3641	asthma         		0.7700	mmm
# 	-1.3607	wasn able      		0.7687	beautiful
# 	-1.3582	gross          		0.7675	hahahaha
# 	-1.3539	is ill         		0.7655	of fun
# 	-1.3529	no iphone      		0.7640	has great
# 	-1.3512	painful        		0.7638	the lord
# 	-1.3504	too fast       		0.7623	celebrating
# 	-1.3482	ripped         		0.7600	right back
# 	-1.3462	surgery        		0.7562	lakers
# 	-1.3459	yuck           		0.7561	long as
# 	-1.3457	unable         		0.7558	in mind
# 	-1.3440	hating         		0.7537	classic
# 	-1.3431	ed mcmahon     		0.7494	whoop
# 	-1.3426	os3            		0.7487	recommend
# 	-1.3421	couldn make    		0.7467	rain rain
# 	-1.3402	crashed        		0.7451	interesting
# 	-1.3369	throw up       		0.7430	rockin
# 	-1.3354	cant           		0.7417	let get
# 	-1.3348	dies           		0.7409	follow them
# 	-1.3343	boo for        		0.7407	hah
# 	-1.3336	what waste     		0.7365	don worry
# 	-1.3311	destroyed      		0.7360	finally
# 	-1.3303	blister        		0.7348	sweetheart
# 	-1.3295	storming       		0.7346	rules
# 	-1.3286	sprained       		0.7343	rocking
# 	-1.3279	stressing      		0.7329	greatest
# 	-1.3278	dislike        		0.7321	just thought
# 	-1.3278	allergic       		0.7321	sad and
# 	-1.3252	ruining        		0.7309	aww thank
# 	-1.3237	no power       		0.7306	coming soon
# 	-1.3230	was hoping     		0.7297	very happy
# 	-1.3225	sleepless night		0.7275	love
# 	-1.3219	poisoning      		0.7250	twittering
# 	-1.3214	hurt           		0.7227	dm me
# 	-1.3199	concert but    		0.7213	now following
# 	-1.3193	horrid         		0.7212	have beautiful
# 	-1.3183	burned         		0.7194	birthday hope
# 	-1.3181	no bueno       		0.7191	awww thanks
# 	-1.3164	trackle        		0.7190	sad he
# 	-1.3162	refuses        		0.7167	tasty
# 	-1.3159	nightmare      		0.7161	mariahcarey
# 	-1.3129	keeps crashing 		0.7152	smart
# 	-1.3095	isn working    		0.7148	dont worry
# 	-1.3088	deleted        		0.7135	poor guy
# 	-1.3077	mad that       		0.7132	bed good
# 	-1.3043	don like       		0.7132	feel sad
# 	-1.3035	urgh           		0.7119	my headache
# 	-1.3026	nauseous       		0.7112	great to
# 	-1.3012	link didn      		0.7102	so exciting
# 	-1.2993	bad news       		0.7097	blast
# 	-1.2978	doesn look     		0.7095	check them
# 	-1.2967	sry            		0.7060	my dear
# 	-1.2953	cancel         		0.7049	tweeters
# 	-1.2944	not impressed  		0.7037	that right
# 	-1.2924	no friends     		0.7028	well worth
# 	-1.2895	never gonna    		0.7022	being sick
# 	-1.2894	bleeding       		0.7015	for follow
# 	-1.2878	anxiety        		0.7015	really cute
# 	-1.2877	so mad         		0.7001	am happy
# 	-1.2877	can find       		0.6993	½ï
# 	-1.2858	feel for       		0.6986	style
# 	-1.2852	is acting      		0.6984	morning good
# 	-1.2840	oh noes        		0.6980	to hurt
# 	-1.2830	sniff          		0.6975	challenge
# 	-1.2825	cant find      		0.6969	much fun
# 	-1.2822	last show      		0.6963	quotes
# 	-1.2788	not here       		0.6963	perhaps
# 	-1.2783	bye to         		0.6948	surprise
# 	-1.2754	hasnt          		0.6944	cool http
# 	-1.2735	sigh           		0.6942	exciting
# 	-1.2727	sucked         		0.6934	have great
# 	-1.2726	sorry          		0.6926	140
# 	-1.2707	damaged        		0.6912	tweeties
# 	-1.2704	hacked         		0.6892	happy sunday
# 	-1.2703	falling apart  		0.6886	tune
# 	-1.2700	still waiting  		0.6872	to ya
# 	-1.2674	annoyed        		0.6862	depends
# 	-1.2663	oww            		0.6852	good
# 	-1.2652	expensive      		0.6852	follow him
# 	-1.2646	migraines      		0.6850	bride
# 	-1.2636	strep          		0.6849	tell all
# 	-1.2627	scared         		0.6849	diversity
# 	-1.2624	messed         		0.6844	great
# 	-1.2607	didn get       		0.6842	very cute
# 	-1.2605	gonna rain     		0.6839	the follow
# 	-1.2585	never going    		0.6835	doing great
# 	-1.2581	boo hoo        		0.6835	liked it
# 	-1.2559	blocked        		0.6827	tweet was
# 	-1.2549	by myself      		0.6810	tomfelton
# 	-1.2544	hit my         		0.6801	follow
# 	-1.2542	arghhh         		0.6798	sick of
# 	-1.2538	im lonely      		0.6782	indeed
# 	-1.2524	so sorry       		0.6771	great job
# 	-1.2517	none           		0.6753	hurts from
# 	-1.2505	but me         		0.6734	the ff
# 	-1.2504	not getting    		0.6724	it great
# 	-1.2496	couldn go      		0.6718	museum
# 	-1.2491	feeling down   		0.6718	adventure
# 	-1.2479	blows          		0.6712	strawberry
# 	-1.2456	jailbreak      		0.6691	good plan
# 	-1.2454	dull           		0.6687	for asking
# 	-1.2451	cloudy         		0.6676	creative
# 	-1.2451	wishes he      		0.6667	hi there
# 	-1.2433	freezing       		0.6663	sang
# 	-1.2426	last episode   		0.6660	remember to
# 	-1.2398	david carradine		0.6650	youngq
# 	-1.2389	coulda         		0.6649	too cute
# 	-1.2359	447            		0.6641	chill
# 	-1.2356	need new       		0.6640	re cool
# 	-1.2346	why did        		0.6628	have nice
# 	-1.2331	for maintenance		0.6623	dig
# 	-1.2326	why does       		0.6622	annoying you
# 	-1.2323	attacked       		0.6620	love my
# 	-1.2323	lost           		0.6609	blessed day
# 	-1.2322	be missed      		0.6609	song of
# 	-1.2313	wish           		0.6600	delicious
# 	-1.2305	suicide        		0.6596	join us
# 	-1.2290	why wont       		0.6593	banksyart2
# 	-1.2267	sunburnt       		0.6592	heaven
# 	-1.2264	allergies      		0.6577	keep the
# 	-1.2260	my hopes       		0.6573	check this
# 	-1.2257	fell           		0.6571	he he
# 	-1.2226	isn going      		0.6570	all is
# 	-1.2212	arent          		0.6565	sexy
# 	-1.2182	postponed      		0.6563	re very
# 	-1.2174	cool especially		0.6562	smile on
# 	-1.2170	was looking    		0.6545	got my
# 	-1.2133	rained out     		0.6522	joining
# 	-1.2130	where is       		0.6514	twitterverse
# 	-1.2125	burnt          		0.6509	its good
# 	-1.2117	still havent   		0.6504	hey
# 	-1.2117	fever          		0.6501	allen
# 	-1.2114	ughhhhh        		0.6500	and eating
# 	-1.2109	aww man        		0.6486	added
# 	-1.2108	is leaving     		0.6475	birthday wishes
# 	-1.2103	oh no          		0.6467	hope to
# 	-1.2096	wont work      		0.6438	worship
# 	-1.2095	oh dear        		0.6436	take look
# 	-1.2082	dentist        		0.6433	geek
# 	-1.2082	sore           		0.6432	listening
# 	-1.2073	threw up       		0.6428	some fun
# 	-1.2072	won load       		0.6426	at http
# 	-1.2055	wishing was    		0.6416	sir
# 	-1.2035	not having     		0.6415	all good
# 	-1.2005	uncomfortable  		0.6412	worry
# 	-1.2001	saddens me     		0.6412	hahah
# 	-1.1999	wish was       		0.6398	have wonderful
# 	-1.1998	acting up      		0.6397	recommendations
# 	-1.1994	suck           		0.6396	retweet
# 	-1.1986	depression     		0.6394	may the
# 	-1.1983	iphone software		0.6377	love it
# 	-1.1980	what happened  		0.6372	myspace com
# 	-1.1976	grr            		0.6364	how cute
# 	-1.1926	getting old    		0.6360	tweeps
# 	-1.1914	icky           		0.6357	incredible
# 	-1.1903	couldnt        		0.6350	most welcome
# 	-1.1901	unwell         		0.6341	you too
# 	-1.1890	very sorry     		0.6317	all love
# 	-1.1879	having issues  		0.6313	sick so
# 	-1.1860	ughh           		0.6311	spreading
# 	-1.1835	worrying       		0.6310	appreciate
# 	-1.1815	be long        		0.6307	nothing like
# 	-1.1793	stuck          		0.6300	is perfect
# 	-1.1786	missing her    		0.6300	happy mother
# 	-1.1771	but no         		0.6263	had fun
# 	-1.1768	error          		0.6251	or pay
# 	-1.1744	hit by         		0.6235	loves the
# 	-1.1739	wisdom teeth   		0.6231	hurts and
# 	-1.1709	getting cold   		0.6230	content
# 	-1.1693	couldn even    		0.6228	are great
# 	-1.1686	smh            		0.6228	plenty
# 	-1.1669	rash           		0.6226	all about
# 	-1.1653	where did      		0.6217	at www
# 	-1.1646	and stuck      		0.6213	you really
# 	-1.1645	when will      		0.6207	who came
# 	-1.1643	wishing        		0.6195	yes
# 	-1.1621	all alone      		0.6188	lyrics
# 	-1.1615	running out    		0.6179	rocked
# 	-1.1610	ewww           		0.6176	spread the
# 	-1.1594	fawcett        		0.6147	fave
# 	-1.1581	cruel          		0.6144	no sorry
# 	-1.1572	issues with    		0.6141	you need
# 	-1.1567	no money       		0.6128	aplusk
# 	-1.1564	itchy          		0.6119	morning how
# 	-1.1563	wish lived     		0.6111	just ordered
# 	-1.1556	they took      		0.6100	is loving
# 	-1.1537	without him    		0.6099	nerd
# 	-1.1534	accident       		0.6096	oh and
# 	-1.1529	should ve      		0.6069	yup
# 	-1.1526	wimbledon      		0.6052	sick and
# 	-1.1523	is broken      		0.6041	fine
# 	-1.1522	so confused    		0.6036	ask
# 	-1.1505	gonna suck     		0.6016	homemade
# 	-1.1498	boring         		0.6014	got twitter
# 	-1.1488	would but      		0.6014	thanks http
# 	-1.1486	pathetic       		0.6005	how love
