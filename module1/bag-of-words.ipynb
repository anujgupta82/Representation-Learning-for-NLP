# %% [markdown]
# # A simple sentiment prototype

# %%
import os  # manipulate paths
import pandas as pd  # SQL-like operations and convenience functions
import joblib  # save and load models

# %% [markdown]
# Download the Sentiment140 data from [their website](http://help.sentiment140.com/for-students) and set `DATA_DIR` to the directory in which you have put the `CSV` files.

# %%
DATA_DIR = "trainingandtestdata"
training_csv_file = os.path.join(DATA_DIR, 'training.1600000.processed.noemoticon.csv')

# %% [markdown]
# ## A peek at the data

# %%
names = ('polarity', 'id', 'date', 'query', 'author', 'text')
df = pd.read_csv(training_csv_file, encoding='latin1', names=names)

# %%
pd.options.display.max_colwidth = 140  # allow wide columns
df.head()  # show first 5 rows
# Out:
#    polarity          id                          date     query  \
# 0         0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1         0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2         0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3         0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4         0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#             author  \
# 0  _TheSpecialOne_
# 1    scotthamilton
# 2         mattycus
# 3          ElleCTF
# 4           Karoli
#
#                                                                                                                   text
# 0  @switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D
# 1      is upset that he can't update his Facebook by texting it... and might cry as a result  School today also. Blah!
# 2                            @Kenichan I dived many times for the ball. Managed to save 50%  The rest go out of bounds
# 3                                                                      my whole body feels itchy and like its on fire
# 4      @nationwideclass no, it's not behaving at all. i'm mad. why am i here? because I can't see you all over there.

# %%
df.tail()
# Out:
#          polarity          id                          date     query  \
# 1599995         4  2193601966  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599996         4  2193601969  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599997         4  2193601991  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599998         4  2193602064  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599999         4  2193602129  Tue Jun 16 08:40:50 PDT 2009  NO_QUERY
#
#                   author  \
# 1599995  AmandaMarie1028
# 1599996      TheWDBoards
# 1599997           bpbabe
# 1599998     tinydiamondz
# 1599999   RyanTrevMorris
#
#                                                                                    text
# 1599995                        Just woke up. Having no school is the best feeling ever
# 1599996  TheWDB.com - Very cool to hear old Walt interviews!  â« http://blip.fm/~8bmta
# 1599997                       Are you ready for your MoJo Makeover? Ask me for details
# 1599998               Happy 38th Birthday to my boo of alll time!!! Tupac Amaru Shakur
# 1599999                  happy #charitytuesday @theNSPCC @SparksCharity @SpeakingUpH4H

# %%
df['polarity'].replace({0: -1, 4: 1}, inplace=True)
text = df['text']
target = df['polarity'].values

# %%
print(len(target), len(text))
# Out:
# 1600000 1600000

# %% [markdown]
# ## Train the model
#
# Set 20% of the data aside to test the trained model

# %%
from sklearn.cross_validation import train_test_split

text_train, text_validation, target_train, target_validation = (
    train_test_split(text, target, test_size=0.2, random_state=42)
)

# %% [markdown]
# Build a pipeline

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.linear_model import LogisticRegressionCV
from sklearn.pipeline import Pipeline

vectorizer = CountVectorizer(ngram_range=(1, 2), max_features=100000)
feature_selector = SelectKBest(chi2, k=5000)
classifier = LogisticRegressionCV(n_jobs=4)

# %% [markdown]
# This next cell took ~3 minutes to run on my machine

# %%
if os.path.exists('model.pkl'):
    sentiment_pipeline = joblib.load('model.pkl')
else:
    sentiment_pipeline = Pipeline((
        ('v', vectorizer),
        ('f', feature_selector),
        ('c', classifier)
    ))
    sentiment_pipeline.fit(text_train, target_train)
    joblib.dump(sentiment_pipeline, 'model.pkl');

# %% [markdown]
# ## Test the model

# %%
print(sentiment_pipeline.predict(['bad', 'good', "didnt like", "today was a good day", "i hate this product"]))
# Out:
# [-1  1 -1  1 -1]

# %%
for text, target in zip(text_validation[:10], target_validation[:10]):
    print(sentiment_pipeline.predict([text])[0], target, '\t', text)
# Out:
# 1 -1 	 @chrishasboobs AHHH I HOPE YOUR OK!!!
# 1 -1 	 @misstoriblack cool , i have no tweet apps  for my razr 2
# 1 -1 	 @TiannaChaos i know  just family drama. its lame.hey next time u hang out with kim n u guys like have a sleepover or whatever, ill call u
# -1 -1 	 School email won't open  and I have geography stuff on there to revise! *Stupid School* :'(
# 1 -1 	 upper airways problem
# -1 -1 	 Going to miss Pastor's sermon on Faith...
# 1 1 	 on lunch....dj should come eat with me
# -1 -1 	 @piginthepoke oh why are you feeling like that?
# -1 -1 	 gahh noo!peyton needs to live!this is horrible
# 1 1 	 @mrstessyman thank you glad you like it! There is a product review bit on the site  Enjoy knitting it!

# %%
sentiment_pipeline.score(text_validation, target_validation)
# Out:
# 0.79942812500000004

# %% [markdown]
# ## What did the model learn?

# %%
feature_names = sentiment_pipeline.steps[0][1].get_feature_names()
feature_names = [feature_names[i] for i in 
                 sentiment_pipeline.steps[1][1].get_support(indices=True)]

def show_most_informative_features(feature_names, clf, n=1000):
    coefs_with_fns = sorted(zip(clf.coef_[0], feature_names))
    top = zip(coefs_with_fns[:n], coefs_with_fns[:-(n + 1):-1])
    for (coef_1, fn_1), (coef_2, fn_2) in top:
        print("\t%.4f\t%-15s\t\t%.4f\t%-15s" % (coef_1, fn_1, coef_2, fn_2))

# %%
show_most_informative_features(feature_names, sentiment_pipeline.steps[2][1], n=500)
# Out:
# 	-3.4628	not happy      		2.6750	no problem
# 	-3.2794	clean me       		2.6244	no worries
# 	-2.9125	not looking    		2.5657	cannot wait
# 	-2.9124	inaperfectworld		2.3216	cant wait
# 	-2.9110	sad            		2.2859	no prob
# 	-2.8527	passed away    		2.2517	smiling
# 	-2.6970	sadly          		2.1924	nothing wrong
# 	-2.6421	not nice       		2.1093	not bad
# 	-2.6333	gutted         		2.0198	sad sad
# 	-2.6265	not cool       		1.9122	congratulations
# 	-2.6044	no luck        		1.7787	fuzzball
# 	-2.6044	disappointing  		1.7751	no probs
# 	-2.4926	heartbreaking  		1.7722	welcome
# 	-2.4771	sadd           		1.7376	musicmonday
# 	-2.4683	heartbroken    		1.6985	hate hate
# 	-2.4286	boohoo         		1.6670	yayyy
# 	-2.4184	rip            		1.6627	smile
# 	-2.4156	not fun        		1.6291	woooo
# 	-2.4029	poor           		1.6259	thankyou
# 	-2.3998	dontyouhate    		1.5961	just sayin
# 	-2.3856	bummer         		1.5958	smiles
# 	-2.3646	depressed      		1.5762	proud
# 	-2.3349	bummed         		1.5680	heheh
# 	-2.3247	cancelled      		1.5599	followfriday
# 	-2.3185	unfortunately  		1.5565	laughter
# 	-2.3119	not excited    		1.5494	thanks
# 	-2.3048	depressing     		1.5486	amusing
# 	-2.2977	upsetting      		1.5291	my pleasure
# 	-2.2942	headache       		1.5291	gracias
# 	-2.2716	nooooo         		1.5015	yayy
# 	-2.2643	pakcricket     		1.4982	goodsex
# 	-2.2612	funeral        		1.4792	feel free
# 	-2.2482	devastated     		1.4786	giggle
# 	-2.2342	boooo          		1.4735	hehehe
# 	-2.2308	hurts          		1.4685	thumbs up
# 	-2.2298	air france     		1.4580	grin
# 	-2.2223	ruined         		1.4309	blessed
# 	-2.2030	let down       		1.4294	can wait
# 	-2.1970	misses         		1.4087	hihi
# 	-2.1958	noooooo        		1.4024	thank
# 	-2.1841	taking forever 		1.3995	yummm
# 	-2.1810	missin         		1.3947	yey
# 	-2.1793	poorly         		1.3946	congrats
# 	-2.1780	homesick       		1.3920	woohoo
# 	-2.1776	booooo         		1.3889	blessings
# 	-2.1724	not good       		1.3815	honored
# 	-2.1713	fed up         		1.3811	crack me
# 	-2.1649	toothache      		1.3810	wooooo
# 	-2.1486	dissapointed   		1.3710	excellent
# 	-2.1344	ftl            		1.3682	feels good
# 	-2.1287	disappointed   		1.3526	whoo
# 	-2.1198	not enjoying   		1.3477	heey
# 	-2.1184	saddest        		1.3444	for following
# 	-2.1134	what wrong     		1.3400	social media
# 	-2.1131	so mean        		1.3279	heehee
# 	-2.1052	unhappy        		1.3276	thx
# 	-2.0992	unfair         		1.3275	teehee
# 	-2.0963	missing        		1.3240	don forget
# 	-2.0849	sick           		1.3150	pleasure
# 	-2.0778	saddened       		1.3132	cheers
# 	-2.0753	meanie         		1.3095	tnx
# 	-2.0658	farrah         		1.2997	heya
# 	-2.0646	sadness        		1.2949	sweetest
# 	-2.0491	booo           		1.2829	howdy
# 	-2.0476	huhuhu         		1.2727	awesomeness
# 	-2.0465	died           		1.2688	appreciated
# 	-2.0284	never reply    		1.2670	reward
# 	-2.0279	not fair       		1.2670	loving
# 	-2.0278	condolences    		1.2657	peaceful
# 	-2.0121	sadface        		1.2645	glad
# 	-2.0119	sucks          		1.2506	stay tuned
# 	-2.0107	cries          		1.2493	relaxed
# 	-2.0044	wouldn let     		1.2486	nice work
# 	-2.0039	migraine       		1.2422	tommcfly http
# 	-1.9938	dreading       		1.2394	alike
# 	-1.9892	hates          		1.2366	hehe
# 	-1.9805	lonely         		1.2365	hooray
# 	-1.9644	no fun         		1.2337	excited
# 	-1.9478	not funny      		1.2332	sad just
# 	-1.9455	not feeling    		1.2325	found you
# 	-1.9449	canceled       		1.2285	heh
# 	-1.9410	won let        		1.2267	blessing
# 	-1.9253	noooooooooo    		1.2233	stoked
# 	-1.9144	tragic         		1.2158	yaay
# 	-1.9073	fathers day    		1.2130	fabulous
# 	-1.9018	isn good       		1.2127	goood
# 	-1.9017	drop by        		1.2110	sad but
# 	-1.8982	won work       		1.2010	too funny
# 	-1.8905	happy father   		1.1997	ugh hate
# 	-1.8784	cramps         		1.1996	ftw
# 	-1.8782	sold out       		1.1994	yaaay
# 	-1.8722	miss           		1.1990	happy
# 	-1.8709	injured        		1.1939	np
# 	-1.8683	good bye       		1.1890	goooood
# 	-1.8656	unfortunate    		1.1853	why thank
# 	-1.8655	iran           		1.1853	woot
# 	-1.8644	ate all        		1.1847	thankful
# 	-1.8603	upset          		1.1839	yay
# 	-1.8535	unloved        		1.1838	learning how
# 	-1.8508	jury duty      		1.1798	dont forget
# 	-1.8486	breaks my      		1.1762	adorable
# 	-1.8436	no new         		1.1711	yummy
# 	-1.8378	sux            		1.1674	grateful
# 	-1.8346	broke          		1.1577	hee
# 	-1.8344	crying         		1.1564	yumm
# 	-1.8307	neda           		1.1521	thanx
# 	-1.8211	not liking     		1.1422	hello
# 	-1.8092	not found      		1.1393	god is
# 	-1.8071	not coming     		1.1370	nicely
# 	-1.8069	crashes        		1.1367	goodnight
# 	-1.8017	still no       		1.1294	lovin
# 	-1.7991	horrible       		1.1248	quote
# 	-1.7977	wont let       		1.1238	wonderful
# 	-1.7931	not feelin     		1.1224	rocks
# 	-1.7902	why won        		1.1196	sick but
# 	-1.7810	no good        		1.1174	awesome
# 	-1.7777	hiccups        		1.1163	kindly
# 	-1.7744	coughing       		1.1138	gooood
# 	-1.7707	feel well      		1.1127	gotta love
# 	-1.7699	alas           		1.1048	inspired
# 	-1.7675	hayfever       		1.1039	how sweet
# 	-1.7651	throwing up    		1.1033	sure thing
# 	-1.7627	happy fathers  		1.1033	bed night
# 	-1.7620	bnp            		1.0981	goodluck
# 	-1.7545	noooo          		1.0960	handy
# 	-1.7483	nooooooo       		1.0896	yum
# 	-1.7462	downside       		1.0884	we come
# 	-1.7451	nowhere to     		1.0882	don mind
# 	-1.7428	unfortunatly   		1.0875	bom dia
# 	-1.7419	wishin         		1.0772	hilarious
# 	-1.7418	why must       		1.0713	be sad
# 	-1.7414	there goes     		1.0621	yessss
# 	-1.7411	whyyyy         		1.0602	praise
# 	-1.7394	whats wrong    		1.0596	hugh
# 	-1.7342	didn win       		1.0503	enjoying
# 	-1.7320	never got      		1.0500	about time
# 	-1.7300	sadder         		1.0498	pleased
# 	-1.7286	won come       		1.0462	at last
# 	-1.7226	awful          		1.0451	relaxing
# 	-1.7158	failed         		1.0433	w00t
# 	-1.7142	stinks         		1.0407	funniest
# 	-1.7112	ughhh          		1.0399	go girl
# 	-1.7044	ughhhh         		1.0365	opinion
# 	-1.7043	ouchie         		1.0329	laughing
# 	-1.7031	frustrated     		1.0308	you want
# 	-1.6914	hurting        		1.0285	tetris
# 	-1.6889	boooooo        		1.0215	knew you
# 	-1.6819	broken         		1.0143	cute
# 	-1.6807	struggling     		1.0130	hola
# 	-1.6773	bad luck       		1.0125	positive
# 	-1.6762	shame          		1.0092	colorblindfish
# 	-1.6724	summer school  		1.0091	hiya
# 	-1.6713	hmph           		1.0075	fantastic
# 	-1.6679	fml            		1.0065	re good
# 	-1.6664	ugh            		1.0054	shine
# 	-1.6660	rainin         		1.0046	come join
# 	-1.6660	disabled       		1.0037	greetings
# 	-1.6639	laid off       		1.0035	amazing
# 	-1.6604	disappointment 		1.0033	aww thanks
# 	-1.6586	is down        		1.0015	brilliant
# 	-1.6524	feeling ill    		1.0001	realhughjackman
# 	-1.6439	pity           		0.9999	pumped
# 	-1.6387	terrible       		0.9986	goodmorning
# 	-1.6372	yucky          		0.9980	the poor
# 	-1.6360	won see        		0.9963	power of
# 	-1.6326	neglected      		0.9934	made my
# 	-1.6319	heartburn      		0.9892	cool
# 	-1.6310	ouch           		0.9884	awsome
# 	-1.6304	not ready      		0.9882	thanking
# 	-1.6298	not showing    		0.9870	ttyl
# 	-1.6268	answer me      		0.9856	loves
# 	-1.6252	not very       		0.9851	wooo
# 	-1.6218	ignoring me    		0.9826	days until
# 	-1.6205	stung          		0.9800	bliss
# 	-1.6190	disappeared    		0.9800	like plan
# 	-1.6179	need hug       		0.9782	handsome
# 	-1.6171	3gs            		0.9779	multiply
# 	-1.6163	miserable      		0.9768	enjoy
# 	-1.6092	closed         		0.9748	familiar
# 	-1.6086	ache           		0.9724	unique
# 	-1.6056	infection      		0.9723	curious
# 	-1.6049	bronchitis     		0.9647	it fun
# 	-1.6043	noes           		0.9637	woo
# 	-1.5960	without me     		0.9627	thnx
# 	-1.5950	sucky          		0.9620	glad could
# 	-1.5946	stranded       		0.9564	ugh im
# 	-1.5928	disconnected   		0.9535	cutest
# 	-1.5886	feel ill       		0.9521	happiness
# 	-1.5856	hate           		0.9500	try it
# 	-1.5785	the er         		0.9489	you wanna
# 	-1.5742	down today     		0.9475	adore
# 	-1.5730	loosing        		0.9464	just wanted
# 	-1.5664	ran over       		0.9427	sweet
# 	-1.5642	bad times      		0.9425	inspiring
# 	-1.5633	mms            		0.9415	prefer
# 	-1.5568	but but        		0.9397	mmmm
# 	-1.5544	goodbyes       		0.9371	good work
# 	-1.5473	gotta wait     		0.9363	myweakness
# 	-1.5438	ick            		0.9359	luck
# 	-1.5396	bed alone      		0.9332	new favorite
# 	-1.5373	losing         		0.9327	better now
# 	-1.5360	no fair        		0.9310	lovely
# 	-1.5343	not well       		0.9282	aw thanks
# 	-1.5329	coursework     		0.9282	cutie
# 	-1.5326	an end         		0.9278	sleep tight
# 	-1.5317	screwed        		0.9212	17 again
# 	-1.5306	not available  		0.9189	relax
# 	-1.5290	having trouble 		0.9166	productive
# 	-1.5226	rest in        		0.9163	holla
# 	-1.5206	father day     		0.9150	heyyy
# 	-1.5198	saddens        		0.9115	funny
# 	-1.5198	argh           		0.9104	helps
# 	-1.5182	crappy         		0.9103	is fun
# 	-1.5177	twitter won    		0.9093	back later
# 	-1.5155	dammit         		0.9079	ahaha
# 	-1.5145	gloomy         		0.9044	beauty
# 	-1.5111	suffering      		0.9027	love being
# 	-1.5094	iranelection   		0.9027	everyone should
# 	-1.5080	worried        		0.8922	bored bored
# 	-1.5058	but live       		0.8915	heyy
# 	-1.5047	leaving me     		0.8865	just need
# 	-1.5046	dangit         		0.8852	ya tomorrow
# 	-1.5038	you thank      		0.8835	neat
# 	-1.5016	spilled        		0.8834	compliment
# 	-1.5006	never answer   		0.8832	mmmmm
# 	-1.5000	never see      		0.8816	sooo excited
# 	-1.4992	shitty         		0.8781	gorgeous
# 	-1.4918	sunburned      		0.8779	iamdiddy
# 	-1.4899	damnit         		0.8765	its great
# 	-1.4888	to reality     		0.8718	ty
# 	-1.4884	scratched      		0.8713	was sick
# 	-1.4871	got cold       		0.8705	that cute
# 	-1.4843	swollen        		0.8701	you might
# 	-1.4841	tear           		0.8686	hahaha
# 	-1.4803	not playing    		0.8636	lets
# 	-1.4756	fail           		0.8604	bom
# 	-1.4734	isnt working   		0.8591	www
# 	-1.4717	stolen         		0.8573	lovee
# 	-1.4706	some reason    		0.8565	perfect
# 	-1.4673	sicky          		0.8551	always good
# 	-1.4667	cried          		0.8543	good evening
# 	-1.4634	regents        		0.8522	nice
# 	-1.4620	tears          		0.8509	great news
# 	-1.4580	shattered      		0.8495	of course
# 	-1.4539	frustrating    		0.8492	fly with
# 	-1.4533	expired        		0.8460	loves it
# 	-1.4530	burnt my       		0.8415	entertaining
# 	-1.4522	being mean     		0.8328	giveaway
# 	-1.4521	no1            		0.8316	great meeting
# 	-1.4501	forgot my      		0.8311	join me
# 	-1.4488	iphone update  		0.8261	hurts like
# 	-1.4467	noooooooo      		0.8250	feedback
# 	-1.4457	rained         		0.8210	humor
# 	-1.4448	goodbye        		0.8171	me laugh
# 	-1.4441	humid          		0.8170	surprised
# 	-1.4433	nooo           		0.8162	ha
# 	-1.4407	crushed        		0.8156	just wondering
# 	-1.4402	stressed       		0.8130	good choice
# 	-1.4381	wheres         		0.8130	even better
# 	-1.4345	how come       		0.8119	anytime
# 	-1.4337	cry            		0.8114	in case
# 	-1.4261	divorce        		0.8092	mrtweet
# 	-1.4230	boo            		0.8079	featured
# 	-1.4220	froze          		0.8063	fresh
# 	-1.4217	suspended      		0.8047	here come
# 	-1.4217	wishing could  		0.8013	recommendation
# 	-1.4189	owie           		0.7996	hello there
# 	-1.4181	bad day        		0.7986	hi
# 	-1.4167	delayed        		0.7975	celebration
# 	-1.4162	sob            		0.7955	nighty
# 	-1.4138	no sun         		0.7954	aha
# 	-1.4124	missed         		0.7952	certainly
# 	-1.4108	huhu           		0.7949	peace
# 	-1.4101	rubbish        		0.7940	went well
# 	-1.4077	ashamed        		0.7929	hell yeah
# 	-1.4057	drained        		0.7923	watch out
# 	-1.4051	no go          		0.7921	success
# 	-1.4023	but nobody     		0.7921	laughs
# 	-1.3996	30 tag         		0.7866	ð¼ð
# 	-1.3966	something wrong		0.7837	enjoyed
# 	-1.3957	cannot         		0.7827	talented
# 	-1.3948	we lost        		0.7826	clever
# 	-1.3945	arghh          		0.7825	100 followers
# 	-1.3933	ignored        		0.7816	chillin
# 	-1.3931	woe            		0.7809	great week
# 	-1.3926	why can        		0.7797	how are
# 	-1.3891	torn           		0.7788	love this
# 	-1.3880	failing        		0.7787	genius
# 	-1.3865	much pain      		0.7783	coolest
# 	-1.3855	worst          		0.7768	get sick
# 	-1.3772	sniffle        		0.7768	much better
# 	-1.3769	not able       		0.7765	http blip
# 	-1.3739	disgusting     		0.7763	yesss
# 	-1.3739	arg            		0.7761	conversation
# 	-1.3731	bugger         		0.7752	chatting
# 	-1.3728	bit my         		0.7731	sweet dreams
# 	-1.3723	no word        		0.7729	useful
# 	-1.3708	vet            		0.7720	chilling
# 	-1.3683	lost my        		0.7718	case you
# 	-1.3681	leaves         		0.7704	mmm
# 	-1.3603	mourning       		0.7700	beautiful
# 	-1.3602	too fast       		0.7700	haha
# 	-1.3601	really ill     		0.7692	the lord
# 	-1.3596	grrrrrr        		0.7683	hahahaha
# 	-1.3589	grrr           		0.7677	worth it
# 	-1.3576	ripped         		0.7668	right back
# 	-1.3499	asthma         		0.7639	headache and
# 	-1.3480	gross          		0.7625	in mind
# 	-1.3422	dies           		0.7617	of fun
# 	-1.3421	painful        		0.7610	your thinking
# 	-1.3420	wasn able      		0.7599	has great
# 	-1.3412	yuck           		0.7598	celebrating
# 	-1.3398	throw up       		0.7589	appreciate that
# 	-1.3391	couldn make    		0.7572	lakers
# 	-1.3380	surgery        		0.7538	long as
# 	-1.3380	destroyed      		0.7514	whoop
# 	-1.3377	cant           		0.7497	rockin
# 	-1.3367	dislike        		0.7480	interesting
# 	-1.3358	hating         		0.7466	let get
# 	-1.3346	is ill         		0.7466	classic
# 	-1.3345	stressing      		0.7433	recommend
# 	-1.3339	unable         		0.7425	don worry
# 	-1.3319	ruining        		0.7401	hah
# 	-1.3305	no iphone      		0.7400	rain rain
# 	-1.3302	crashed        		0.7390	rocking
# 	-1.3290	ed mcmahon     		0.7384	sweetheart
# 	-1.3233	poisoning      		0.7357	coming soon
# 	-1.3231	storming       		0.7347	finally
# 	-1.3223	blister        		0.7339	just thought
# 	-1.3212	hurt           		0.7318	sad and
# 	-1.3198	os3            		0.7301	follow them
# 	-1.3194	what waste     		0.7295	love
# 	-1.3181	horrid         		0.7288	rules
# 	-1.3180	allergic       		0.7282	very happy
# 	-1.3177	sprained       		0.7274	dm me
# 	-1.3162	boo for        		0.7269	greatest
# 	-1.3155	trackle        		0.7253	twittering
# 	-1.3148	was hoping     		0.7241	aww thank
# 	-1.3136	refuses        		0.7206	mariahcarey
# 	-1.3121	isn working    		0.7174	now following
# 	-1.3116	burned         		0.7161	awww thanks
# 	-1.3115	sleepless night		0.7144	smart
# 	-1.3095	nightmare      		0.7137	tasty
# 	-1.3058	bad news       		0.7119	dont worry
# 	-1.3055	no power       		0.7110	great to
# 	-1.3053	doesn look     		0.7109	have beautiful
# 	-1.3051	no bueno       		0.7100	blast
# 	-1.3047	don like       		0.7089	being sick
# 	-1.3023	concert but    		0.7080	bed good
# 	-1.3023	cancel         		0.7071	so exciting
# 	-1.3016	urgh           		0.7066	poor guy
# 	-1.2999	deleted        		0.7056	birthday hope
# 	-1.2976	bleeding       		0.7043	sad he
# 	-1.2953	sry            		0.7042	check them
# 	-1.2939	oh noes        		0.7038	my dear
# 	-1.2939	keeps crashing 		0.7034	feel sad
# 	-1.2933	mad that       		0.7030	my headache
# 	-1.2906	nauseous       		0.7022	that right
# 	-1.2899	can find       		0.7016	quotes
# 	-1.2895	bye to         		0.7014	am happy
# 	-1.2892	so mad         		0.6997	tweeters
# 	-1.2891	anxiety        		0.6989	to hurt
# 	-1.2891	cant find      		0.6988	½ï
# 	-1.2890	no friends     		0.6985	style
# 	-1.2880	never gonna    		0.6980	really cute
# 	-1.2875	not impressed  		0.6973	perhaps
# 	-1.2858	not here       		0.6969	well worth
# 	-1.2851	feel for       		0.6963	exciting
# 	-1.2832	hasnt          		0.6960	much fun
# 	-1.2832	last show      		0.6947	surprise
# 	-1.2812	link didn      		0.6940	challenge
# 	-1.2785	sniff          		0.6939	have great
# 	-1.2778	hacked         		0.6936	tweeties
# 	-1.2761	sigh           		0.6898	to ya
# 	-1.2759	sorry          		0.6896	happy sunday
# 	-1.2750	is acting      		0.6881	liked it
# 	-1.2674	expensive      		0.6878	for follow
# 	-1.2664	scared         		0.6868	morning good
# 	-1.2646	sucked         		0.6865	140
# 	-1.2619	didn get       		0.6864	bride
# 	-1.2616	still waiting  		0.6862	tweet was
# 	-1.2615	damaged        		0.6856	tune
# 	-1.2614	annoyed        		0.6855	the follow
# 	-1.2595	oww            		0.6847	good
# 	-1.2569	blows          		0.6844	doing great
# 	-1.2566	but me         		0.6840	tomfelton
# 	-1.2554	messed         		0.6838	diversity
# 	-1.2553	never going    		0.6827	cool http
# 	-1.2539	hit my         		0.6822	great
# 	-1.2529	none           		0.6815	follow
# 	-1.2529	strep          		0.6797	great job
# 	-1.2525	falling apart  		0.6795	very cute
# 	-1.2516	migraines      		0.6794	depends
# 	-1.2504	gonna rain     		0.6792	indeed
# 	-1.2496	so sorry       		0.6791	follow him
# 	-1.2494	blocked        		0.6775	sick of
# 	-1.2491	last episode   		0.6768	tell all
# 	-1.2490	dull           		0.6747	the ff
# 	-1.2489	not getting    		0.6713	remember to
# 	-1.2473	by myself      		0.6706	hi there
# 	-1.2434	boo hoo        		0.6704	it great
# 	-1.2433	arghhh         		0.6697	adventure
# 	-1.2402	jailbreak      		0.6690	sang
# 	-1.2398	couldn go      		0.6685	museum
# 	-1.2390	coulda         		0.6671	hurts from
# 	-1.2385	attacked       		0.6669	for asking
# 	-1.2374	wishes he      		0.6656	strawberry
# 	-1.2364	cloudy         		0.6650	too cute
# 	-1.2362	be missed      		0.6650	dig
# 	-1.2353	freezing       		0.6650	chill
# 	-1.2350	im lonely      		0.6632	youngq
# 	-1.2339	lost           		0.6629	love my
# 	-1.2332	david carradine		0.6628	keep the
# 	-1.2316	feeling down   		0.6622	creative
# 	-1.2308	suicide        		0.6613	delicious
# 	-1.2301	wish           		0.6610	good plan
# 	-1.2276	need new       		0.6606	check this
# 	-1.2276	why does       		0.6604	all is
# 	-1.2270	fell           		0.6594	join us
# 	-1.2263	postponed      		0.6593	have nice
# 	-1.2262	why did        		0.6578	he he
# 	-1.2235	sunburnt       		0.6570	song of
# 	-1.2227	allergies      		0.6569	sexy
# 	-1.2199	447            		0.6561	got my
# 	-1.2163	burnt          		0.6556	twitterverse
# 	-1.2162	isn going      		0.6544	joining
# 	-1.2145	is leaving     		0.6538	and eating
# 	-1.2143	fever          		0.6533	heaven
# 	-1.2140	my hopes       		0.6530	smile on
# 	-1.2135	was looking    		0.6527	annoying you
# 	-1.2135	arent          		0.6526	re very
# 	-1.2134	for maintenance		0.6526	hey
# 	-1.2111	oh no          		0.6524	re cool
# 	-1.2109	sore           		0.6517	allen
# 	-1.2108	where is       		0.6516	its good
# 	-1.2102	dentist        		0.6516	blessed day
# 	-1.2080	why wont       		0.6493	added
# 	-1.2079	aww man        		0.6491	banksyart2
# 	-1.2069	wishing was    		0.6482	some fun
# 	-1.2066	depression     		0.6466	worship
# 	-1.2059	oh dear        		0.6448	at http
# 	-1.2038	suck           		0.6447	hope to
# 	-1.2035	cool especially		0.6444	take look
# 	-1.2033	uncomfortable  		0.6439	listening
# 	-1.2030	rained out     		0.6428	all good
# 	-1.2028	getting old    		0.6425	worry
# 	-1.2017	still havent   		0.6424	recommendations
# 	-1.2004	not having     		0.6422	birthday wishes
# 	-1.2000	wish was       		0.6421	hahah
# 	-1.1979	threw up       		0.6403	sir
# 	-1.1960	ughhhhh        		0.6397	may the
# 	-1.1959	icky           		0.6396	have wonderful
# 	-1.1936	acting up      		0.6390	love it
# 	-1.1928	wont work      		0.6368	retweet
# 	-1.1928	couldnt        		0.6365	geek
# 	-1.1919	what happened  		0.6363	tweeps
# 	-1.1915	worrying       		0.6358	you too
# 	-1.1906	saddens me     		0.6349	appreciate
# 	-1.1896	grr            		0.6338	myspace com
# 	-1.1866	won load       		0.6333	how cute
# 	-1.1822	hit by         		0.6324	happy mother
# 	-1.1783	ughh           		0.6324	spreading
# 	-1.1779	iphone software		0.6316	incredible
# 	-1.1779	stuck          		0.6292	is perfect
# 	-1.1769	unwell         		0.6275	nothing like
# 	-1.1767	but no         		0.6261	all love
# 	-1.1739	very sorry     		0.6255	are great
# 	-1.1732	having issues  		0.6245	had fun
# 	-1.1730	be long        		0.6238	all about
# 	-1.1697	running out    		0.6234	loves the
# 	-1.1683	error          		0.6230	most welcome
# 	-1.1682	cruel          		0.6213	sick so
# 	-1.1676	wishing        		0.6194	yes
# 	-1.1672	ewww           		0.6190	content
# 	-1.1666	all alone      		0.6185	rocked
# 	-1.1639	smh            		0.6181	you really
# 	-1.1622	missing her    		0.6178	at www
# 	-1.1622	no money       		0.6173	plenty
# 	-1.1616	itchy          		0.6163	or pay
# 	-1.1610	rash           		0.6158	lyrics
# 	-1.1600	wisdom teeth   		0.6155	just ordered
# 	-1.1569	is broken      		0.6148	no sorry
# 	-1.1568	where did      		0.6146	you need
# 	-1.1566	would but      		0.6141	fave
# 	-1.1562	getting cold   		0.6125	is loving
# 	-1.1560	and stuck      		0.6119	who came
# 	-1.1555	when will      		0.6116	morning how
# 	-1.1552	wimbledon      		0.6111	oh and
# 	-1.1543	so confused    		0.6104	hurts and
# 	-1.1522	should ve      		0.6098	spread the
# 	-1.1519	pathetic       		0.6083	aplusk
# 	-1.1515	fawcett        		0.6078	nerd
# 	-1.1503	issues with    		0.6076	yup
# 	-1.1502	they took      		0.6072	sick and
# 	-1.1501	couldn even    		0.6041	got twitter
# 	-1.1491	isnt           		0.6027	fine
# 	-1.1473	wish lived     		0.6025	homemade
# 	-1.1468	accident       		0.6018	ask
# 	-1.1464	not working    		0.6006	how love
# 	-1.1439	boring         		0.5995	be sick
