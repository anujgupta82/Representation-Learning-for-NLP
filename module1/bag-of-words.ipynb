# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # A simple sentiment prototype

# %%
import os  # manipulate paths
import pandas as pd  # SQL-like operations and convenience functions
import joblib  # save and load models

# %% [markdown]
# Download the Sentiment140 data from [their website](http://help.sentiment140.com/for-students) or directly from [Standford site](http://cs.stanford.edu/people/alecmgo/trainingandtestdata.zip) and set `DATA_DIR` to the directory in which you have put the `CSV` files.

# %%
DATA_DIR = "./../data"
training_csv_file = os.path.join(DATA_DIR, 'training.1600000.processed.noemoticon.csv')

# %%
training_csv_file
# Out:
# './../data/training.1600000.processed.noemoticon.csv'

# %% [markdown]
# ## A peek at the data

# %%
names = ('polarity', 'id', 'date', 'query', 'author', 'text')
df = pd.read_csv(training_csv_file, encoding='latin1', names=names)

# %%
pd.options.display.max_colwidth = 140  # allow wide columns
df.head()  # show first 5 rows
# Out:
#    polarity          id                          date     query  \
# 0         0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1         0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2         0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3         0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4         0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#             author  \
# 0  _TheSpecialOne_
# 1    scotthamilton
# 2         mattycus
# 3          ElleCTF
# 4           Karoli
#
#                                                                                                                   text
# 0  @switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D
# 1      is upset that he can't update his Facebook by texting it... and might cry as a result  School today also. Blah!
# 2                            @Kenichan I dived many times for the ball. Managed to save 50%  The rest go out of bounds
# 3                                                                      my whole body feels itchy and like its on fire
# 4      @nationwideclass no, it's not behaving at all. i'm mad. why am i here? because I can't see you all over there.

# %%
df.tail()
# Out:
#          polarity          id                          date     query  \
# 1599995         4  2193601966  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599996         4  2193601969  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599997         4  2193601991  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599998         4  2193602064  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599999         4  2193602129  Tue Jun 16 08:40:50 PDT 2009  NO_QUERY
#
#                   author  \
# 1599995  AmandaMarie1028
# 1599996      TheWDBoards
# 1599997           bpbabe
# 1599998     tinydiamondz
# 1599999   RyanTrevMorris
#
#                                                                                    text
# 1599995                        Just woke up. Having no school is the best feeling ever
# 1599996  TheWDB.com - Very cool to hear old Walt interviews!  â« http://blip.fm/~8bmta
# 1599997                       Are you ready for your MoJo Makeover? Ask me for details
# 1599998               Happy 38th Birthday to my boo of alll time!!! Tupac Amaru Shakur
# 1599999                  happy #charitytuesday @theNSPCC @SparksCharity @SpeakingUpH4H

# %%
df['polarity'].replace({0: -1, 4: 1}, inplace=True)
text = df['text']
target = df['polarity'].values

# %%
print(len(target), len(text))
# Out:
# (1600000, 1600000)

# %% [markdown]
# ## Train the model
#
# Set 20% of the data aside to test the trained model

# %%
from sklearn.cross_validation import train_test_split

text_train, text_validation, target_train, target_validation = (
    train_test_split(text, target, test_size=0.2, random_state=42)
)
# Out:
# /Users/airwoot/opt/virtual_env/Representation-Learning-for-NLP/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# Build a pipeline

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.linear_model import LogisticRegressionCV
from sklearn.pipeline import Pipeline

vectorizer = CountVectorizer(ngram_range=(1, 2), max_features=100000)
feature_selector = SelectKBest(chi2, k=5000)
classifier = LogisticRegressionCV(n_jobs=4)

# %% [markdown]
# This next cell took ~3 minutes to run on my machine

# %%
if os.path.exists('model.pkl'):
    sentiment_pipeline = joblib.load('model.pkl')
else:
    sentiment_pipeline = Pipeline((
        ('v', vectorizer),
        ('f', feature_selector),
        ('c', classifier)
    ))
    sentiment_pipeline.fit(text_train, target_train)
    joblib.dump(sentiment_pipeline, 'model.pkl');

# %% [markdown]
# ## Test the model

# %%
print(sentiment_pipeline.predict(['bad', 'good', "didnt like", "today was a good day", "i hate this product"]))
# Out:
# [-1  1 -1  1 -1]

# %%
for text, target in zip(text_validation[:10], target_validation[:10]):
    print(sentiment_pipeline.predict([text])[0], target, '\t', text)
# Out:
# (1, -1, '\t', u'@chrishasboobs AHHH I HOPE YOUR OK!!! ')
# (1, -1, '\t', u'@misstoriblack cool , i have no tweet apps  for my razr 2')
# (1, -1, '\t', u'@TiannaChaos i know  just family drama. its lame.hey next time u hang out with kim n u guys like have a sleepover or whatever, ill call u')
# (-1, -1, '\t', u"School email won't open  and I have geography stuff on there to revise! *Stupid School* :'(")
# (1, -1, '\t', u'upper airways problem ')
# (-1, -1, '\t', u"Going to miss Pastor's sermon on Faith... ")
# (1, 1, '\t', u'on lunch....dj should come eat with me ')
# (-1, -1, '\t', u'@piginthepoke oh why are you feeling like that? ')
# (-1, -1, '\t', u'gahh noo!peyton needs to live!this is horrible ')
# (1, 1, '\t', u'@mrstessyman thank you glad you like it! There is a product review bit on the site  Enjoy knitting it!')

# %%
sentiment_pipeline.score(text_validation, target_validation)
# Out:
# 0.79943750000000002

# %% [markdown]
# ## What did the model learn?

# %%
feature_names = sentiment_pipeline.steps[0][1].get_feature_names()
feature_names = [feature_names[i] for i in 
                 sentiment_pipeline.steps[1][1].get_support(indices=True)]

def show_most_informative_features(feature_names, clf, n=1000):
    coefs_with_fns = sorted(zip(clf.coef_[0], feature_names))
    top = zip(coefs_with_fns[:n], coefs_with_fns[:-(n + 1):-1])
    for (coef_1, fn_1), (coef_2, fn_2) in top:
        print("\t%.4f\t%-15s\t\t%.4f\t%-15s" % (coef_1, fn_1, coef_2, fn_2))

# %%
show_most_informative_features(feature_names, sentiment_pipeline.steps[2][1], n=500)
# Out:
# 	-3.4605	not happy      		2.6788	no problem
# 	-3.2820	clean me       		2.6236	no worries
# 	-2.9184	not looking    		2.5599	cannot wait
# 	-2.9167	inaperfectworld		2.3206	cant wait
# 	-2.9130	sad            		2.2872	no prob
# 	-2.8566	passed away    		2.2462	smiling
# 	-2.6917	sadly          		2.1924	nothing wrong
# 	-2.6387	not nice       		2.1125	not bad
# 	-2.6384	gutted         		2.0138	sad sad
# 	-2.6232	not cool       		1.9194	congratulations
# 	-2.6003	no luck        		1.7807	fuzzball
# 	-2.5969	disappointing  		1.7781	no probs
# 	-2.4976	heartbreaking  		1.7736	welcome
# 	-2.4807	sadd           		1.7362	musicmonday
# 	-2.4713	heartbroken    		1.7098	hate hate
# 	-2.4325	boohoo         		1.6675	smile
# 	-2.4235	rip            		1.6655	yayyy
# 	-2.4127	not fun        		1.6282	woooo
# 	-2.4052	poor           		1.6259	thankyou
# 	-2.4027	dontyouhate    		1.5978	just sayin
# 	-2.3918	bummer         		1.5928	smiles
# 	-2.3718	depressed      		1.5764	proud
# 	-2.3434	bummed         		1.5710	heheh
# 	-2.3333	cancelled      		1.5599	laughter
# 	-1.6580	disappointment 		1.0020	realhughjackman
# 	-1.6550	feeling ill    		0.9999	brilliant
# 	-1.6480	pity           		0.9994	goodmorning
# 	-1.6389	won see        		0.9991	the poor
# 	-1.6375	terrible       		0.9979	pumped
# 	-1.6357	yucky          		0.9959	power of
# 	-1.6345	heartburn      		0.9929	made my
# 	-1.6336	neglected      		0.9904	cool
# 	-1.6332	not showing    		0.9900	thanking
# 	-1.6318	ouch           		0.9887	awsome
# 	-1.6277	not ready      		0.9879	wooo
# 	-1.6274	not very       		0.9842	ttyl
# 	-1.6236	stung          		0.9838	days until
# 	-1.6234	ignoring me    		0.9811	like plan
# 	-1.6221	answer me      		0.9809	loves
# 	-1.6198	need hug       		0.9798	bliss
# 	-1.6167	3gs            		0.9776	handsome
# 	-1.6164	miserable      		0.9774	multiply
# 	-1.6142	ache           		0.9759	enjoy
# 	-1.6142	disappeared    		0.9757	curious
# 	-1.6068	closed         		0.9751	familiar
# 	-1.6068	bronchitis     		0.9733	unique
# 	-1.6010	infection      		0.9642	woo
# 	-1.6009	noes           		0.9640	it fun
# 	-1.5984	stranded       		0.9631	thnx
# 	-1.5960	disconnected   		0.9615	glad could
# 	-1.5955	without me     		0.9594	ugh im
# 	-1.5923	sucky          		0.9548	happiness
# 	-1.5915	feel ill       		0.9541	cutest
# 	-1.5840	hate           		0.9517	try it
# 	-1.5774	down today     		0.9499	just wanted
# 	-1.5770	the er         		0.9482	you wanna
# 	-1.5738	loosing        		0.9458	adore
# 	-1.5704	ran over       		0.9441	inspiring
# 	-1.5655	mms            		0.9417	prefer
# 	-1.5625	bad times      		0.9397	mmmm
# 	-1.5575	goodbyes       		0.9395	sweet
# 	-1.5574	but but        		0.9376	good work
# 	-1.5505	gotta wait     		0.9365	luck
# 	-1.5473	ick            		0.9356	new favorite
# 	-1.5409	bed alone      		0.9349	better now
# 	-1.5389	no fair        		0.9340	myweakness
# 	-1.5360	screwed        		0.9296	lovely
# 	-1.5353	not well       		0.9294	sleep tight
# 	-1.5341	losing         		0.9293	aw thanks
# 	-1.5340	not available  		0.9268	cutie
# 	-1.5316	coursework     		0.9192	17 again
# 	-1.5299	having trouble 		0.9170	relax
# 	-1.5289	an end         		0.9137	productive
# 	-1.5214	saddens        		0.9124	holla
# 	-1.5209	rest in        		0.9122	heyyy
# 	-1.5206	dammit         		0.9107	funny
# 	-1.5201	argh           		0.9105	is fun
# 	-1.5191	twitter won    		0.9100	ahaha
# 	-1.5181	father day     		0.9097	helps
# 	-1.5178	crappy         		0.9070	beauty
# 	-1.5141	gloomy         		0.9069	back later
# 	-1.5132	suffering      		0.9046	everyone should
# 	-1.5106	iranelection   		0.9024	love being
# 	-1.5097	worried        		0.8929	heyy
# 	-1.5088	but live       		0.8926	bored bored
# 	-1.5083	you thank      		0.8871	ya tomorrow
# 	-1.5075	dangit         		0.8851	just need
# 	-1.5070	leaving me     		0.8838	sooo excited
# 	-1.5036	shitty         		0.8835	mmmmm
# 	-1.5023	spilled        		0.8830	compliment
# 	-1.5009	never see      		0.8822	neat
# 	-1.5004	never answer   		0.8801	gorgeous
# 	-1.4902	got cold       		0.8769	its great
# 	-1.4901	scratched      		0.8747	ty
# 	-1.4899	to reality     		0.8743	iamdiddy
# 	-1.4887	tear           		0.8740	was sick
# 	-1.4881	sunburned      		0.8724	that cute
# 	-1.4874	damnit         		0.8716	you might
# 	-1.4838	not playing    		0.8682	hahaha
# 	-1.4797	swollen        		0.8628	lets
# 	-1.4759	isnt working   		0.8606	bom
# 	-1.4753	some reason    		0.8601	www
# 	-1.4704	sicky          		0.8540	lovee
# 	-1.4692	stolen         		0.8536	always good
# 	-1.4687	fail           		0.8533	good evening
# 	-1.4649	regents        		0.8526	great news
# 	-1.4634	cried          		0.8522	perfect
# 	-1.4623	tears          		0.8520	nice
# 	-1.4561	expired        		0.8487	of course
# 	-1.4559	shattered      		0.8467	fly with
# 	-1.4557	burnt my       		0.8458	loves it
# 	-1.4549	being mean     		0.8407	entertaining
# 	-1.4528	no1            		0.8321	giveaway
# 	-1.4521	frustrating    		0.8306	great meeting
# 	-1.4519	iphone update  		0.8301	join me
# 	-1.4502	rained         		0.8280	hurts like
# 	-1.4497	noooooooo      		0.8240	feedback
# 	-1.4491	goodbye        		0.8197	humor
# 	-1.4477	forgot my      		0.8183	surprised
# 	-1.4457	stressed       		0.8164	ha
# 	-1.4453	nooo           		0.8160	me laugh
# 	-1.4416	humid          		0.8148	good choice
# 	-1.4390	how come       		0.8141	just wondering
# 	-1.4389	crushed        		0.8120	in case
# 	-1.4352	wheres         		0.8110	even better
# 	-1.4271	divorce        		0.8102	mrtweet
# 	-1.4252	froze          		0.8101	anytime
# 	-1.4252	wishing could  		0.8096	featured
# 	-1.4249	cry            		0.8062	fresh
# 	-1.4194	suspended      		0.8051	here come
# 	-1.4194	owie           		0.8018	recommendation
# 	-1.4192	bad day        		0.8009	hello there
# 	-1.4185	delayed        		0.7973	certainly
# 	-1.4174	boo            		0.7967	nighty
# 	-1.4169	no sun         		0.7966	hi
# 	-1.4147	rubbish        		0.7961	went well
# 	-1.4140	sob            		0.7951	celebration
# 	-1.4130	missed         		0.7946	aha
# 	-1.4090	huhu           		0.7941	peace
# 	-1.4083	drained        		0.7937	success
# 	-1.4071	no go          		0.7928	hell yeah
# 	-1.4049	but nobody     		0.7916	laughs
# 	-1.4028	ashamed        		0.7911	watch out
# 	-1.4018	30 tag         		0.7886	ð¼ð
# 	-1.3979	something wrong		0.7859	enjoyed
# 	-1.3973	arghh          		0.7842	100 followers
# 	-1.3967	why can        		0.7837	chillin
# 	-1.3959	woe            		0.7821	great week
# 	-1.3954	we lost        		0.7808	talented
# 	-1.3946	cannot         		0.7796	how are
# 	-1.3912	ignored        		0.7795	clever
# 	-1.3907	torn           		0.7791	conversation
# 	-1.3881	much pain      		0.7787	coolest
# 	-1.3866	failing        		0.7775	chatting
# 	-1.3815	worst          		0.7771	http blip
# 	-1.3795	sniffle        		0.7770	love this
# 	-1.3789	not able       		0.7769	genius
# 	-1.3772	arg            		0.7768	get sick
# 	-1.3757	bit my         		0.7761	yesss
# 	-1.3750	vet            		0.7760	much better
# 	-1.3745	no word        		0.7730	case you
# 	-1.3711	leaves         		0.7725	mmm
# 	-1.3706	lost my        		0.7723	useful
# 	-1.3700	disgusting     		0.7712	chilling
# 	-1.3694	bugger         		0.7706	sweet dreams
# 	-1.3635	grrr           		0.7690	hahahaha
# 	-1.3621	mourning       		0.7687	beautiful
# 	-1.3621	grrrrrr        		0.7682	worth it
# 	-1.3605	really ill     		0.7676	the lord
# 	-1.3569	too fast       		0.7667	haha
# 	-1.3552	ripped         		0.7665	headache and
# 	-1.3526	asthma         		0.7659	right back
# 	-1.3523	gross          		0.7616	has great
# 	-1.3461	painful        		0.7616	of fun
# 	-1.3449	wasn able      		0.7615	in mind
# 	-1.3428	yuck           		0.7612	celebrating
# 	-1.3413	surgery        		0.7600	your thinking
# 	-1.3412	couldn make    		0.7594	appreciate that
# 	-1.3402	throw up       		0.7585	lakers
# 	-1.3397	hating         		0.7542	long as
# 	-1.3394	dies           		0.7510	whoop
# 	-1.3375	destroyed      		0.7499	classic
# 	-1.3368	cant           		0.7464	rockin
# 	-1.3367	is ill         		0.7454	recommend
# 	-1.3349	crashed        		0.7450	let get
# 	-1.3338	unable         		0.7430	interesting
# 	-1.3337	stressing      		0.7424	rain rain
# 	-1.3328	dislike        		0.7390	hah
# 	-1.3315	no iphone      		0.7381	don worry
# 	-1.3315	ruining        		0.7375	finally
# 	-1.3293	ed mcmahon     		0.7374	rocking
# 	-1.3266	storming       		0.7360	sweetheart
# 	-1.3262	blister        		0.7345	sad and
# 	-1.3241	poisoning      		0.7332	just thought
# 	-1.3215	what waste     		0.7329	coming soon
# 	-1.3211	allergic       		0.7317	follow them
# 	-1.3207	os3            		0.7313	rules
# 	-1.3200	horrid         		0.7297	greatest
# 	-1.3197	sprained       		0.7289	very happy
# 	-1.3194	hurt           		0.7269	love
# 	-1.3187	was hoping     		0.7259	aww thank
# 	-1.3183	boo for        		0.7256	twittering
# 	-1.3171	trackle        		0.7250	dm me
# 	-1.3149	refuses        		0.7196	mariahcarey
# 	-1.3148	burned         		0.7187	now following
# 	-1.3127	nightmare      		0.7180	awww thanks
# 	-1.3118	isn working    		0.7153	tasty
# 	-1.3100	sleepless night		0.7130	dont worry
# 	-1.3079	no power       		0.7129	smart
# 	-1.3066	don like       		0.7121	have beautiful
# 	-1.3050	concert but    		0.7111	blast
# 	-1.3042	doesn look     		0.7107	great to
# 	-1.3039	no bueno       		0.7097	bed good
# 	-1.3037	bad news       		0.7091	poor guy
# 	-1.3029	deleted        		0.7090	so exciting
# 	-1.3019	urgh           		0.7076	being sick
# 	-1.2999	cancel         		0.7061	check them
# 	-1.2968	bleeding       		0.7053	my headache
# 	-1.2957	sry            		0.7052	feel sad
# 	-1.2954	mad that       		0.7050	my dear
# 	-1.2935	keeps crashing 		0.7042	birthday hope
# 	-1.2930	nauseous       		0.7038	that right
# 	-1.2913	oh noes        		0.7035	sad he
# 	-1.2911	anxiety        		0.7019	tweeters
# 	-1.2910	never gonna    		0.7009	am happy
# 	-1.2909	so mad         		0.7005	to hurt
# 	-1.2906	not impressed  		0.6998	quotes
# 	-1.2906	no friends     		0.6987	really cute
# 	-1.2884	feel for       		0.6982	well worth
# 	-1.2874	cant find      		0.6974	much fun
# 	-1.2871	can find       		0.6969	style
# 	-1.2863	bye to         		0.6968	½ï
# 	-1.2840	last show      		0.6962	exciting
# 	-1.2833	not here       		0.6959	perhaps
# 	-1.2818	hasnt          		0.6952	challenge
# 	-1.2812	link didn      		0.6949	have great
# 	-1.2794	sniff          		0.6937	tweeties
# 	-1.2777	is acting      		0.6934	surprise
# 	-1.2756	hacked         		0.6898	happy sunday
# 	-1.2755	sorry          		0.6896	to ya
# 	-1.2729	sigh           		0.6893	140
# 	-1.2682	sucked         		0.6880	for follow
# 	-1.2658	scared         		0.6873	morning good
# 	-1.2653	still waiting  		0.6872	tune
# 	-1.2650	expensive      		0.6868	bride
# 	-1.2647	damaged        		0.6859	the follow
# 	-1.2635	annoyed        		0.6857	tweet was
# 	-1.2621	didn get       		0.6856	liked it
# 	-1.2615	oww            		0.6853	good
# 	-1.2583	never going    		0.6850	doing great
# 	-1.2568	hit my         		0.6836	cool http
# 	-1.2564	but me         		0.6835	tomfelton
# 	-1.2562	none           		0.6832	diversity
# 	-1.2555	messed         		0.6832	great
# 	-1.2554	strep          		0.6827	follow
# 	-1.2544	blows          		0.6821	depends
# 	-1.2543	falling apart  		0.6808	indeed
# 	-1.2539	migraines      		0.6807	very cute
# 	-1.2532	gonna rain     		0.6805	follow him
# 	-1.2511	blocked        		0.6793	sick of
# 	-1.2504	not getting    		0.6789	great job
# 	-1.2496	so sorry       		0.6776	tell all
# 	-1.2494	by myself      		0.6761	the ff
# 	-1.2485	last episode   		0.6721	it great
# 	-1.2477	dull           		0.6712	remember to
# 	-1.2463	arghhh         		0.6707	adventure
# 	-1.2453	boo hoo        		0.6700	hi there
# 	-1.2441	couldn go      		0.6698	for asking
# 	-1.2430	jailbreak      		0.6693	hurts from
# 	-1.2418	coulda         		0.6689	museum
# 	-1.2397	cloudy         		0.6679	strawberry
# 	-1.2397	wishes he      		0.6673	sang
# 	-1.2387	freezing       		0.6655	chill
# 	-1.2363	be missed      		0.6652	too cute
# 	-1.2359	attacked       		0.6645	creative
# 	-1.2354	im lonely      		0.6642	youngq
# 	-1.2343	feeling down   		0.6632	dig
# 	-1.2341	lost           		0.6632	love my
# 	-1.2336	david carradine		0.6621	good plan
# 	-1.2335	suicide        		0.6610	delicious
# 	-1.2316	wish           		0.6607	join us
# 	-1.2310	need new       		0.6606	have nice
# 	-1.2303	why does       		0.6599	keep the
# 	-1.2298	why did        		0.6598	check this
# 	-1.2264	fell           		0.6593	all is
# 	-1.2250	sunburnt       		0.6592	song of
# 	-1.2249	postponed      		0.6588	sexy
# 	-1.2239	allergies      		0.6571	he he
# 	-1.2205	447            		0.6558	heaven
# 	-1.2187	isn going      		0.6540	twitterverse
# 	-1.2168	my hopes       		0.6540	smile on
# 	-1.2162	arent          		0.6539	joining
# 	-1.2148	was looking    		0.6533	re very
# 	-1.2137	is leaving     		0.6530	got my
# 	-1.2131	burnt          		0.6524	re cool
# 	-1.2131	for maintenance		0.6521	hey
# 	-1.2128	oh no          		0.6519	and eating
# 	-1.2121	fever          		0.6516	annoying you
# 	-1.2101	where is       		0.6514	its good
# 	-1.2101	aww man        		0.6510	blessed day
# 	-1.2092	why wont       		0.6509	allen
# 	-1.2087	sore           		0.6488	banksyart2
# 	-1.2078	dentist        		0.6475	added
# 	-1.2070	wishing was    		0.6463	worship
# 	-1.2060	rained out     		0.6458	some fun
# 	-1.2060	oh dear        		0.6454	take look
# 	-1.2048	still havent   		0.6446	at http
# 	-1.2040	depression     		0.6443	hope to
# 	-1.2039	cool especially		0.6435	hahah
# 	-1.2037	uncomfortable  		0.6432	listening
# 	-1.2022	not having     		0.6430	recommendations
# 	-1.2010	threw up       		0.6429	birthday wishes
# 	-1.1992	wish was       		0.6413	all good
# 	-1.1988	getting old    		0.6411	may the
# 	-1.1983	ughhhhh        		0.6399	sir
# 	-1.1962	acting up      		0.6393	geek
# 	-1.1962	suck           		0.6392	worry
# 	-1.1956	wont work      		0.6388	retweet
# 	-1.1951	icky           		0.6381	have wonderful
# 	-1.1946	what happened  		0.6368	love it
# 	-1.1936	grr            		0.6349	tweeps
# 	-1.1931	saddens me     		0.6342	myspace com
# 	-1.1896	couldnt        		0.6338	incredible
# 	-1.1896	worrying       		0.6337	you too
# 	-1.1872	won load       		0.6336	spreading
# 	-1.1819	ughh           		0.6335	happy mother
# 	-1.1801	hit by         		0.6335	appreciate
# 	-1.1798	stuck          		0.6332	how cute
# 	-1.1795	unwell         		0.6293	is perfect
# 	-1.1788	iphone software		0.6291	nothing like
# 	-1.1771	be long        		0.6278	all love
# 	-1.1771	but no         		0.6249	are great
# 	-1.1760	very sorry     		0.6239	had fun
# 	-1.1752	having issues  		0.6234	loves the
# 	-1.1726	error          		0.6229	sick so
# 	-1.1680	running out    		0.6223	most welcome
# 	-1.1664	wishing        		0.6220	all about
# 	-1.1653	all alone      		0.6208	content
# 	-1.1652	smh            		0.6196	plenty
# 	-1.1651	ewww           		0.6195	yes
# 	-1.1637	missing her    		0.6185	at www
# 	-1.1634	cruel          		0.6184	you really
# 	-1.1631	rash           		0.6178	rocked
# 	-1.1614	no money       		0.6172	lyrics
# 	-1.1612	wisdom teeth   		0.6161	no sorry
# 	-1.1608	where did      		0.6158	fave
# 	-1.1605	itchy          		0.6156	or pay
# 	-1.1597	when will      		0.6148	you need
# 	-1.1584	getting cold   		0.6138	just ordered
# 	-1.1579	and stuck      		0.6134	morning how
# 	-1.1567	is broken      		0.6130	who came
# 	-1.1555	so confused    		0.6113	hurts and
# 	-1.1555	wimbledon      		0.6110	spread the
# 	-1.1551	would but      		0.6110	oh and
# 	-1.1531	issues with    		0.6109	is loving
# 	-1.1530	they took      		0.6103	aplusk
# 	-1.1525	should ve      		0.6083	nerd
# 	-1.1523	couldn even    		0.6077	yup
# 	-1.1523	isnt           		0.6065	sick and
# 	-1.1518	fawcett        		0.6038	fine
# 	-1.1503	pathetic       		0.6031	got twitter
# 	-1.1502	accident       		0.6022	homemade
# 	-1.1501	wish lived     		0.6022	ask
# 	-1.1478	boring         		0.6001	how love
# 	-1.1461	wishes         		0.5988	be sick
